// %% [markdown]
// ## Research example assignment 2
//
// Anh Nguyen Tran
//
// Religion, Education, and Views on Abortion: Basic Example Exercise
//
// 02/08/2024

// %% [markdown]
// ### 1. Write a paragraph about your hypotheses
// [Your answer here should explain:
//
// 1. What are your dependent variables? Why do they interest you?
// 2. What are your independent variables? What direction to you hypothesize will be the relationship between your dependent variable and your dependent variables?
// 3. Why do you think your dependent variables are associated with your independent variables?
// 4. What are your control variables? Do you think they will show any spurious, intervening, or interactive relationships? Why?]

// %%
// Skip this question for now (will come back to this later)
// Out:
// <style>div.jp-Notebook .datagrid-container {min-height: 448px; }</style>

// %% [markdown]
// ### 1. Setting up your session
//
// In the code cell below, do the following:
//
// 1. set current directory
// 2. set more off
// 3. create log file
// 4. download the data from its source if it's available online
// 5. read the data in [preferably only variables you are going to use]

// %%
cd "/Users/anhnguyentran/Desktop/Grad_Stats_II/soc211_assignments"
// Out:
// /Users/anhnguyentran/Desktop/Grad_Stats_II/soc211_assignments

// %%
set more off
// Out:
// (-set more- irrelevant in this version of Stata)

// %%
log using "Log for Research Assignment 2.log", replace
// Out:
// -------------------------------------------------------------------------------
//       name:  <unnamed>
//        log:  /Users/anhnguyentran/Desktop/Grad_Stats_II/soc211_assignments/Log
// > for Research Assignment 2.log
//   log type:  text
//  opened on:   8 Feb 2024, 09:53:17

// %% [markdown]
// #### Example commands depending on the type of dataset you are loading in
//
// // For people with .dta aka Stata files
//
// * use "/Users/anhnguyentran/Desktop/Grad_Stats_II/soc211_assignments/GSS_2020_panel_stata_1a/gss2020panel_r1a.dta", clear
//
// // For people with csv files
//
// * insheet using "/Users/anhnguyentran/Desktop/Grad_Stats_II/soc211_assignments/agilepredatorsdata20191116.csv", clear
//
// // For people with excel files
//
// * import excel using "/Users/anhnguyentran/Desktop/Grad_Stats_II/soc211_assignments/PIRUS_V4.xlsx", clear
//
// // To load in only certain variables, put the variables you want before "using" for both csv and excel files and before the path directory for stata files
//
// * import excel Loc_Plot_State1 Year_Exposure Plot_Target1 Plot_Target2 Plot_Target3 Violent using /// "/Users/anhnguyentran/Desktop/Grad_Stats_II/soc211_assignments/PIRUS_V4.xlsx", clear

// %%
use "/Users/anhnguyentran/Desktop/Grad_Stats_II/soc211_assignments/GSS_2020_panel_stata_1a/gss2020panel_r1a.dta", clear

// %% [markdown]
// ### 2. Browse the data
//
// Do the following in separate cells. Do do these in separate cells, you will need to use the right click "split cell" option:
//
// 1. Use "describe" to print details about the dataset
// 2. Print the heads and tables of the data using the appropriate magic
// 3. label the unique identifier variable
// 4. Generate a frequency table to show the N for each unit of time if there is data for multiple units in time
// 5. Check for missing data overall and within key categories of analysis (time, independent or dependent variable categories, etc)
// 6. use summarize to create a table with summary statistics for each variable you plan to analyze

// %%
*describe
describe anesid yearid year_1a year_1b year_2 gender1_1a income_1a relig_1a educ_1a race_1a abany_1a hrs1_1a
// Out:
// Variable      Storage   Display    Value
//     name         type    format    label      Variable label
// -------------------------------------------------------------------------------
// anesid          double  %10.0g
// yearid          long    %12.0g
// year_1a         int     %8.0g                 gss year for this respondent
// year_1b         int     %8.0g                 gss year for this respondent
// year_2          int     %8.0g                 gss year for this respondent
// gender1_1a      byte    %8.0g      GENDER     gender of 1st person
// income_1a       byte    %8.0g      INCOME     total family income
// relig_1a        byte    %8.0g      RELIG      r's religious preference
// educ_1a         byte    %8.0g      EDUC       highest year of school completed
// race_1a         byte    %8.0g      RACE       race of respondent
// abany_1a        byte    %8.0g      LABB       abortion if woman wants for any
//                                                 reason
// hrs1_1a         byte    %8.0g      WKHRS      number of hours worked last week

// %%
codebook anesid yearid year_1a year_1b year_2 gender1_1a income_1a relig_1a educ_1a race_1a abany_1a hrs1_1a
// Out:
// -------------------------------------------------------------------------------
// anesid                                                              (unlabeled)
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (double)
//
//                  Range: [154013,171599]               Units: 1
//          Unique values: 1,164                     Missing .: 0/5,215
//        Unique mv codes: 1                        Missing .*: 4,051/5,215
//
//                   Mean:  162719
//              Std. dev.: 5053.66
//
//            Percentiles:     10%       25%       50%       75%       90%
//                          155764    158275    162706    167011    169800
//
// -------------------------------------------------------------------------------
// yearid                                                              (unlabeled)
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (long)
//
//                  Range: [20160001,20182348]           Units: 1
//          Unique values: 5,215                     Missing .: 0/5,215
//
//                   Mean: 2.0e+07
//              Std. dev.: 9851.85
//
//            Percentiles:     10%       25%       50%       75%       90%
//                         2.0e+07   2.0e+07   2.0e+07   2.0e+07   2.0e+07
//
// -------------------------------------------------------------------------------
// year_1a                                            gss year for this respondent
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (int)
//
//                  Range: [2016,2016]                   Units: 1
//          Unique values: 1                         Missing .: 0/5,215
//        Unique mv codes: 1                        Missing .*: 2,348/5,215
//
//             Tabulation: Freq.  Value
//                         2,867  2016
//                         2,348  .i
//
// -------------------------------------------------------------------------------
// year_1b                                            gss year for this respondent
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (int)
//
//                  Range: [2018,2018]                   Units: 1
//          Unique values: 1                         Missing .: 0/5,215
//        Unique mv codes: 1                        Missing .*: 2,867/5,215
//
//             Tabulation: Freq.  Value
//                         2,348  2018
//                         2,867  .i
//
// -------------------------------------------------------------------------------
// year_2                                             gss year for this respondent
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (int)
//
//                  Range: [2020,2020]                   Units: 1
//          Unique values: 1                         Missing .: 0/5,215
//        Unique mv codes: 1                        Missing .*: 3,392/5,215
//
//             Tabulation: Freq.  Value
//                         1,823  2020
//                         3,392  .i
//
// -------------------------------------------------------------------------------
// gender1_1a                                                 gender of 1st person
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: GENDER
//
//                  Range: [1,2]                         Units: 1
//          Unique values: 2                         Missing .: 0/5,215
//        Unique mv codes: 1                        Missing .*: 2,348/5,215
//
//             Tabulation: Freq.   Numeric  Label
//                         1,510         1  male
//                         1,357         2  female
//                         2,348        .i
//
// -------------------------------------------------------------------------------
// income_1a                                                   total family income
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: INCOME
//
//                  Range: [1,12]                        Units: 1
//          Unique values: 12                        Missing .: 0/5,215
//        Unique mv codes: 2                        Missing .*: 2,782/5,215
//
//               Examples: 12    $25,000 or more
//                         12    $25,000 or more
//                         .i
//                         .i
//
// -------------------------------------------------------------------------------
// relig_1a                                               r's religious preference
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: RELIG
//
//                  Range: [1,13]                        Units: 1
//          Unique values: 13                        Missing .: 0/5,215
//        Unique mv codes: 3                        Missing .*: 2,369/5,215
//
//               Examples: 1     protestant
//                         4     none
//                         .i
//                         .i
//
// -------------------------------------------------------------------------------
// educ_1a                                        highest year of school completed
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: EDUC, but 20 nonmissing values are not labeled
//
//                  Range: [0,20]                        Units: 1
//          Unique values: 21                        Missing .: 0/5,215
//        Unique mv codes: 2                        Missing .*: 2,357/5,215
//
//               Examples: 12
//                         16
//                         .i
//                         .i
//
// -------------------------------------------------------------------------------
// race_1a                                                      race of respondent
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: RACE
//
//                  Range: [1,3]                         Units: 1
//          Unique values: 3                         Missing .: 0/5,215
//        Unique mv codes: 1                        Missing .*: 2,348/5,215
//
//             Tabulation: Freq.   Numeric  Label
//                         2,100         1  white
//                           490         2  black
//                           277         3  other
//                         2,348        .i
//
// -------------------------------------------------------------------------------
// abany_1a                                 abortion if woman wants for any reason
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: LABB
//
//                  Range: [1,2]                         Units: 1
//          Unique values: 2                         Missing .: 0/5,215
//        Unique mv codes: 3                        Missing .*: 3,405/5,215
//
//             Tabulation: Freq.   Numeric  Label
//                           837         1  yes
//                           973         2  no
//                            52        .d
//                         3,325        .i
//                            28        .n
//
// -------------------------------------------------------------------------------
// hrs1_1a                                        number of hours worked last week
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: WKHRS, but 77 nonmissing values are not labeled
//
//                  Range: [1,89]                        Units: 1
//          Unique values: 78                        Missing .: 0/5,215
//        Unique mv codes: 3                        Missing .*: 3,569/5,215
//
//               Examples: 42
//                         .i
//                         .i
//                         .i

// %%
// Checking for duplicates to make sure you found the correct unique identifier variable
*This is panel data, so I have to use both the unique case identifying number for the person and the years attach to them

sort anesid yearid
quietly by anesid yearid: gen dup = cond(_N==1, 0, _n)

// %%
// You want this table to show that there are no duplicates (or in other words, all the observations equal 0 in the table)

tab dup
// Out:
//         dup |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |      5,215      100.00      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00

// %%
// Labeling the unique ID variables

label variable anesid "Respodent's ID Number"
label variable yearid "Year ID attached to Respondents"

// %%
// Check to make sure you labeled the variables correctly

codebook anesid yearid
// Out:
// -------------------------------------------------------------------------------
// anesid                                                    Respodent's ID Number
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (double)
//
//                  Range: [154013,171599]               Units: 1
//          Unique values: 1,164                     Missing .: 0/5,215
//        Unique mv codes: 1                        Missing .*: 4,051/5,215
//
//                   Mean:  162719
//              Std. dev.: 5053.66
//
//            Percentiles:     10%       25%       50%       75%       90%
//                          155764    158275    162706    167011    169800
//
// -------------------------------------------------------------------------------
// yearid                                          Year ID attached to Respondents
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (long)
//
//                  Range: [20160001,20182348]           Units: 1
//          Unique values: 5,215                     Missing .: 0/5,215
//
//                   Mean: 2.0e+07
//              Std. dev.: 9851.85
//
//            Percentiles:     10%       25%       50%       75%       90%
//                         2.0e+07   2.0e+07   2.0e+07   2.0e+07   2.0e+07

// %%
// Do summary statistics for all numeric variables, excluding the ID variables
// For nominal variables, use the tab command instead

tab year_1a, missing
tab year_1b, missing
tab year_2, missing
tab gender1_1a, missing
sum income_1a, detail
tab relig_1a, missing
sum educ_1a, detail
tab race_1a, missing
sum hrs1_1a, detail
// Out:
//    gss year |
//    for this |
//  respondent |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//        2016 |      2,867       54.98       54.98
//          .i |      2,348       45.02      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00
//
//    gss year |
//    for this |
//  respondent |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//        2018 |      2,348       45.02       45.02
//          .i |      2,867       54.98      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00
//
//    gss year |
//    for this |
//  respondent |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//        2020 |      1,823       34.96       34.96
//          .i |      3,392       65.04      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00
//
//   gender of |
//  1st person |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//        male |      1,510       28.95       28.95
//      female |      1,357       26.02       54.98
//          .i |      2,348       45.02      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00
//
//                      total family income
// -------------------------------------------------------------
//       Percentiles      Smallest
//  1%            1              1
//  5%            5              1
// 10%            9              1       Obs               2,433
// 25%           11              1       Sum of wgt.       2,433
//
// 50%           12                      Mean           10.93342
//                         Largest       Std. dev.      2.359473
// 75%           12             12
// 90%           12             12       Variance       5.567111
// 95%           12             12       Skewness      -2.808142
// 99%           12             12       Kurtosis       10.59256
//
//           r's religious |
//              preference |      Freq.     Percent        Cum.
// ------------------------+-----------------------------------
//              protestant |      1,380       26.46       26.46
//                catholic |        649       12.44       38.91
//                  jewish |         51        0.98       39.88
//                    none |        620       11.89       51.77
//                   other |         29        0.56       52.33
//                buddhism |         22        0.42       52.75
//                hinduism |         13        0.25       53.00
// other eastern religions |          4        0.08       53.08
//            muslim/islam |         19        0.36       53.44
//      orthodox-christian |          7        0.13       53.58
//               christian |         41        0.79       54.36
//         native american |          4        0.08       54.44
// inter-nondenominational |          7        0.13       54.57
//                      .d |          3        0.06       54.63
//                      .i |      2,348       45.02       99.65
//                      .n |         18        0.35      100.00
// ------------------------+-----------------------------------
//                   Total |      5,215      100.00
//
//               highest year of school completed
// -------------------------------------------------------------
//       Percentiles      Smallest
//  1%            6              0
//  5%            9              0
// 10%           11              1       Obs               2,858
// 25%           12              1       Sum of wgt.       2,858
//
// 50%           13                      Mean           13.73723
//                         Largest       Std. dev.      2.963886
// 75%           16             20
// 90%           18             20       Variance        8.78462
// 95%           19             20       Skewness      -.1855541
// 99%           20             20       Kurtosis       3.820384
//
//     race of |
//  respondent |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//       white |      2,100       40.27       40.27
//       black |        490        9.40       49.66
//       other |        277        5.31       54.98
//          .i |      2,348       45.02      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00
//
//               number of hours worked last week
// -------------------------------------------------------------
//       Percentiles      Smallest
//  1%            4              1
//  5%           15              1
// 10%           21              1       Obs               1,646
// 25%           35              1       Sum of wgt.       1,646
//
// 50%           40                      Mean           40.91434
//                         Largest       Std. dev.      14.40624
// 75%           48             89
// 90%           60             89       Variance       207.5398
// 95%           65             89       Skewness       .1023125
// 99%           83             89       Kurtosis       4.203042

// %% [markdown]
// ### 3. Write a note summarizing what you learned from browsing the data
//
// [your note here]

// %%
// What should I write for this section? (Some suggestions listed below)

// Is the data cross-sectional or panel data?
// What years are represented by your data? How many missing data do you have for your key variables?
// What type of variables (nominal, etc) are the social factors that you are interested in looking at?
// If your dependent variable is numeric, what is the mean or median?
// If your dependent variable is categorical, what is the mode?

// %%
// After you do this, go back to the first Q1 and answer the questions. Come up with a hypothesis! :)

// %% [markdown]
// ### 4. Create univariate histograms of interval ratio variables you plan to analyze.
//
// Write at least 3 forloops to generate histograms for all the variables you plan to analyze. Create titles for each histogram that notes whether it is a dependent, independent, or control variable (you can also note in titles whether control vars control for spurious, intervening, or interactive relationships). Begin with your dependent variables. Then make a note below to describe the shapes of the distributions and their implications for your study.
//
// [your note here]

// %%
// Summary of question 4: Charlie is basically asking you to create histograms with titles for all your numeric variables

histogram income_1a, frequency title("Household Income (Control for Spuriousness)")
// Out:
// (bin=33, start=1, width=.33333333)

// %%
histogram educ_1a, frequency title("Education (Interactive Variable)")
// Out:
// (bin=34, start=0, width=.58823529)

// %%
histogram hrs1_1a, frequency title("Hours Worked (Intervening Variable)")
// Out:
// (bin=32, start=1, width=2.75)

// %%
// I think he might want loop commands for this (maybe idk). Here's an example

foreach x of varlist income_1a educ_1a hrs1_1a {
    histogram `x'
}

// I have no idea why only one histogram shows up and not the other. Clearly both ran. But even in Stata, only one graph
// is generated at a time. Also, you can't insert title options for histograms using a a loop command because it is unique
// for both of them (lol)
// Out:
// (bin=33, start=1, width=.33333333)
// (bin=34, start=0, width=.58823529)
// (bin=32, start=1, width=2.75)

// %% [markdown]
// ### 5. Create univariate count and % frequency tables for all categorical (nominal) variables you plan to analyze
//
// Again, use forloops. Then write a note below with a narrative summary of the distributions and their implications for your study.
//
// [your note here]

// %%
// Charlie didn't say anything about titles here, so let's go ahead and use a loop command

foreach x of varlist year_1a year_1b year_2 gender1_1a income_1a relig_1a educ_1a race_1a abany_1a hrs1_1a {
    replace `x'=. if `x'==.i | `x'==.n | `x'==.d
    tab `x', missing
}
// Out:
// (2,348 real changes made, 2,348 to missing)
//
//    gss year |
//    for this |
//  respondent |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//        2016 |      2,867       54.98       54.98
//           . |      2,348       45.02      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00
// (2,867 real changes made, 2,867 to missing)
//
//    gss year |
//    for this |
//  respondent |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//        2018 |      2,348       45.02       45.02
//           . |      2,867       54.98      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00
// (3,392 real changes made, 3,392 to missing)
//
//    gss year |
//    for this |
//  respondent |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//        2020 |      1,823       34.96       34.96
//           . |      3,392       65.04      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00
// (2,348 real changes made, 2,348 to missing)
//
//   gender of |
//  1st person |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//        male |      1,510       28.95       28.95
//      female |      1,357       26.02       54.98
//           . |      2,348       45.02      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00
// (2,782 real changes made, 2,782 to missing)
//
//       total family |
//             income |      Freq.     Percent        Cum.
// -------------------+-----------------------------------
//       under $1,000 |         39        0.75        0.75
//   $1,000 to $2,999 |         40        0.77        1.51
//   $3,000 to $3,999 |         21        0.40        1.92
//   $4,000 to $4,999 |         15        0.29        2.21
//   $5,000 to $5,999 |         19        0.36        2.57
//   $6,000 to $6,999 |         15        0.29        2.86
//   $7,000 to $7,999 |         22        0.42        3.28
//   $8,000 to $9,999 |         47        0.90        4.18
// $10,000 to $14,999 |        160        3.07        7.25
// $15,000 to $19,999 |        129        2.47        9.72
// $20,000 to $24,999 |        198        3.80       13.52
//    $25,000 or more |      1,728       33.14       46.65
//                  . |      2,782       53.35      100.00
// -------------------+-----------------------------------
//              Total |      5,215      100.00
// (2,369 real changes made, 2,369 to missing)
//
//           r's religious |
//              preference |      Freq.     Percent        Cum.
// ------------------------+-----------------------------------
//              protestant |      1,380       26.46       26.46
//                catholic |        649       12.44       38.91
//                  jewish |         51        0.98       39.88
//                    none |        620       11.89       51.77
//                   other |         29        0.56       52.33
//                buddhism |         22        0.42       52.75
//                hinduism |         13        0.25       53.00
// other eastern religions |          4        0.08       53.08
//            muslim/islam |         19        0.36       53.44
//      orthodox-christian |          7        0.13       53.58
//               christian |         41        0.79       54.36
//         native american |          4        0.08       54.44
// inter-nondenominational |          7        0.13       54.57
//                       . |      2,369       45.43      100.00
// ------------------------+-----------------------------------
//                   Total |      5,215      100.00
// (2,357 real changes made, 2,357 to missing)
//
//     highest year of |
//    school completed |      Freq.     Percent        Cum.
// --------------------+-----------------------------------
// no formal schooling |          2        0.04        0.04
//                   1 |          3        0.06        0.10
//                   2 |          3        0.06        0.15
//                   3 |          3        0.06        0.21
//                   4 |          2        0.04        0.25
//                   5 |          4        0.08        0.33
//                   6 |         31        0.59        0.92
//                   7 |         18        0.35        1.27
//                   8 |         48        0.92        2.19
//                   9 |         59        1.13        3.32
//                  10 |         90        1.73        5.04
//                  11 |        118        2.26        7.31
//                  12 |        824       15.80       23.11
//                  13 |        242        4.64       27.75
//                  14 |        359        6.88       34.63
//                  15 |        137        2.63       37.26
//                  16 |        485        9.30       46.56
//                  17 |        108        2.07       48.63
//                  18 |        149        2.86       51.49
//                  19 |         63        1.21       52.69
//                  20 |        110        2.11       54.80
//                   . |      2,357       45.20      100.00
// --------------------+-----------------------------------
//               Total |      5,215      100.00
// (2,348 real changes made, 2,348 to missing)
//
//     race of |
//  respondent |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//       white |      2,100       40.27       40.27
//       black |        490        9.40       49.66
//       other |        277        5.31       54.98
//           . |      2,348       45.02      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00
// (3,405 real changes made, 3,405 to missing)
//
// abortion if |
// woman wants |
//     for any |
//      reason |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//         yes |        837       16.05       16.05
//          no |        973       18.66       34.71
//           . |      3,405       65.29      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00
// (3,569 real changes made, 3,569 to missing)
//
//   number of |
//       hours |
// worked last |
//        week |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |          5        0.10        0.10
//           2 |          1        0.02        0.12
//           3 |          3        0.06        0.17
//           4 |         11        0.21        0.38
//           5 |          5        0.10        0.48
//           6 |          5        0.10        0.58
//           7 |          3        0.06        0.63
//           8 |         10        0.19        0.82
//           9 |          1        0.02        0.84
//          10 |         16        0.31        1.15
//          11 |          1        0.02        1.17
//          12 |          8        0.15        1.32
//          14 |          2        0.04        1.36
//          15 |         16        0.31        1.67
//          16 |         18        0.35        2.01
//          17 |          4        0.08        2.09
//          18 |          6        0.12        2.21
//          19 |          3        0.06        2.26
//          20 |         46        0.88        3.14
//          21 |          4        0.08        3.22
//          22 |          8        0.15        3.37
//          23 |          5        0.10        3.47
//          24 |         11        0.21        3.68
//          25 |         32        0.61        4.30
//          26 |          9        0.17        4.47
//          27 |          9        0.17        4.64
//          28 |         13        0.25        4.89
//          29 |          2        0.04        4.93
//          30 |         62        1.19        6.12
//          31 |          2        0.04        6.16
//          32 |         39        0.75        6.90
//          33 |          9        0.17        7.08
//          34 |          9        0.17        7.25
//          35 |         45        0.86        8.11
//          36 |         27        0.52        8.63
//          37 |         14        0.27        8.90
//          38 |         17        0.33        9.22
//          39 |         10        0.19        9.42
//          40 |        526       10.09       19.50
//          41 |         12        0.23       19.73
//          42 |         30        0.58       20.31
//          43 |         12        0.23       20.54
//          44 |         11        0.21       20.75
//          45 |         92        1.76       22.51
//          46 |         13        0.25       22.76
//          47 |         10        0.19       22.95
//          48 |         38        0.73       23.68
//          49 |          4        0.08       23.76
//          50 |        138        2.65       26.40
//          51 |          3        0.06       26.46
//          52 |         11        0.21       26.67
//          53 |          6        0.12       26.79
//          54 |          8        0.15       26.94
//          55 |         37        0.71       27.65
//          56 |         12        0.23       27.88
//          57 |          3        0.06       27.94
//          58 |          2        0.04       27.98
//          60 |         82        1.57       29.55
//          61 |          1        0.02       29.57
//          62 |          4        0.08       29.65
//          63 |          3        0.06       29.70
//          64 |          3        0.06       29.76
//          65 |         16        0.31       30.07
//          67 |          2        0.04       30.11
//          68 |          5        0.10       30.20
//          70 |         30        0.58       30.78
//          72 |          5        0.10       30.87
//          73 |          1        0.02       30.89
//          75 |          6        0.12       31.01
//          77 |          1        0.02       31.03
//          78 |          1        0.02       31.05
//          80 |          9        0.17       31.22
//          81 |          1        0.02       31.24
//          83 |          1        0.02       31.26
//          84 |          4        0.08       31.33
//          85 |          1        0.02       31.35
//          86 |          1        0.02       31.37
//   89+ hours |         10        0.19       31.56
//           . |      3,569       68.44      100.00
// ------------+-----------------------------------
//       Total |      5,215      100.00

// %% [markdown]
// ### 6. Make a relevant bivariate table and graph for your study
//
// Make the appropriate a) bivariate table and b) graph dependening on whether your dependent variable is nominal/categorical or interval ratio. If your dependent variable is nominal, make sure it is the row variable in the table. If your independent variable is interval ratio, convert it into an ordinal variable by creating a new variable with 3 to 5 categories each with an equal range of the interval ratio variable. Then use the new ordinal variable as your independent variable in the bivariate table and graph.

// %%
// Choose one dependent variable and one independent you are most interested in

codebook abany_1a
// Out:
// -------------------------------------------------------------------------------
// abany_1a                                 abortion if woman wants for any reason
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: LABB
//
//                  Range: [1,2]                         Units: 1
//          Unique values: 2                         Missing .: 3,405/5,215
//
//             Tabulation: Freq.   Numeric  Label
//                           837         1  yes
//                           973         2  no
//                         3,405         .

// %%
// Cleaning this variable up to make it more interpretable

gen abortion_clean=abany_1a
replace abortion_clean=0 if abortion_clean==2

label variable abortion_clean "does the respondent support women's right to abortion for any reason?"
label define abortion_clean 0 "no" 1 "yes"
label values abortion_clean abortion_clean

codebook abortion_clean
// Out:
// (3,405 missing values generated)
// (973 real changes made)
//
// -------------------------------------------------------------------------------
// abortion_clean                         does the respondent support women's
//                                        right to abortion for any reason?
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (float)
//                  Label: abortion_clean
//
//                  Range: [0,1]                         Units: 1
//          Unique values: 2                         Missing .: 3,405/5,215
//
//             Tabulation: Freq.   Numeric  Label
//                           973         0  no
//                           837         1  yes
//                         3,405         .

// %%
graph hbar (mean) abortion_clean, over(relig_1a) title("Views on Abortion and Religious Affiliation")

// %% [markdown]
// ### 7. Create partial bivariate tables and graphs
//
// For the bivariate table and graph you made for problem 6, split both into partial tables and graphs using one of your nominal/categorical control variables. If your control variable is interval ratio, convert it into an ordinal variable by creating a variable with 3 to 5 categories each with an equal range of the interval ratio variable.  Then use the new ordinal variable as your control variable to create the partial tables and graphs.

// %%
// Choose one more independent variable you care about for this assignment
codebook educ_1a
sum educ_1a
// Out:
// -------------------------------------------------------------------------------
// educ_1a                                        highest year of school completed
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: EDUC, but 20 nonmissing values are not labeled
//
//                  Range: [0,20]                        Units: 1
//          Unique values: 21                        Missing .: 2,357/5,215
//
//               Examples: 12
//                         16
//                         .
//                         .
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//      educ_1a |      2,858    13.73723    2.963886          0         20

// %%
// Converting the numeric variable I care about into a categorical one

gen education=educ_1a
replace education=0 if education<12
replace education=1 if education==12
replace education=2 if education>12

label variable education "what level of education does the respondent have?"
label define education 0 "less than high school" 1 "high school degree" 2 "went into higher education"
label values education education

codebook education
// Out:
// (2,357 missing values generated)
// (379 real changes made)
// (824 real changes made)
// (4,010 real changes made)
//
// -------------------------------------------------------------------------------
// education                     what level of education does the respondent have?
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (float)
//                  Label: education
//
//                  Range: [0,2]                         Units: 1
//          Unique values: 3                         Missing .: 0/5,215
//
//             Tabulation: Freq.   Numeric  Label
//                           381         0  less than high school
//                           824         1  high school degree
//                         4,010         2  went into higher education

// %%
// Run some partial graph

graph hbar (mean) abortion_clean, over(relig_1a) by(education) title("Partial Bivariate Graph")

// %% [markdown]
// ### Interpret of your bivariate and partial tables and graphs
//
// Is there a relationship between your dependent and independent variables? Is it weak, strong, or non-existent? Do adding controls reveal any spurious, intervening, or interactive relationships? Do they conform with your hypotheses? If not, do you have any ideas for why and how you might test the reason why?
//
// [your answer here (refer to first Q1) - Good luck guys]

// %%
log close
// Out:
//       name:  <unnamed>
//        log:  /Users/anhnguyentran/Desktop/Grad_Stats_II/soc211_assignments/Log
// > for Research Assignment 2.log
//   log type:  text
//  closed on:   8 Feb 2024, 09:53:24
// -------------------------------------------------------------------------------
