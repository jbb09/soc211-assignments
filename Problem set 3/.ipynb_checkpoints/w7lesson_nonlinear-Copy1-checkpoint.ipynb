// %% [markdown]
// # Week 7: OLS for non-linear relationships
//
// ## By Charlie Eaton

// %% [markdown]
// Note for writing formulas: here is an awesome wiki dictionary for LaTex code for math symbols: https://oeis.org/wiki/List_of_LaTeX_mathematical_symbols
//
// ## OLS Non-linear relationships:
//
// 1. are nominal/categorical (dummy variables)
//
// 2. change in increments (sequential dummy variables)
//
// 3. change direction or strength abruptly (spline)
//
// 4. change direction gradually (quadratic)
//
// 5. accelerate/decelerate -- i.e. curve (logarithmic)

// %% [markdown]
// ## Do the usual to check out the data

// %%
qui set more off
qui capture log close
qui log using w7lesson_log20200304.log, replace
qui use realrinc age sex race educ yearsjob paeduc PASEI10 using GSS2018w7.dta, clear
*describe
*summarize realrinc age sex race educ yearsjob paeduc
// Out:
// <style>div.jp-Notebook .datagrid-container {min-height: 448px; }</style>

// %% [markdown]
// ## 1. Nominal dummy variables
//
// Creates "0" and "1" indicator variables for each category of a nominal variable.
//
// Add the two nominal variables in our dataset to the code below to create dummy variables for each.

// %%
*This is one of the more effective ways to create dummy variables. Using gen and replace runs the risk of missing values
xi i.sex i.race, noomit

// %%
%head if _n>10
// Out:
// <div>
// <style scoped>
//     .dataframe tbody tr th:only-of-type {
//         vertical-align: middle;
//     }
//
//     .dataframe tbody tr th {
//         vertical-align: top;
//     }
//
//     .dataframe thead th {
//         text-align: right;
//     }
// </style>
// <table border="1" class="dataframe">
//   <thead>
//     <tr style="text-align: right;">
//       <th></th>
//       <th>age</th>
//       <th>educ</th>
//       <th>paeduc</th>
//       <th>sex</th>
//       <th>race</th>
//       <th>yearsjob</th>
//       <th>realrinc</th>
//       <th>PASEI10</th>
//     </tr>
//   </thead>
//   <tbody>
//     <tr>
//       <th>11</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>male</td>
//       <td>white</td>
//       <td>2</td>
//       <td>54480</td>
//       <td>52</td>
//     </tr>
//     <tr>
//       <th>12</th>
//       <td></td>
//       <td></td>
//       <td>iap</td>
//       <td>female</td>
//       <td>other</td>
//       <td>5</td>
//       <td>8512.5</td>
//       <td>.</td>
//     </tr>
//     <tr>
//       <th>13</th>
//       <td></td>
//       <td></td>
//       <td>dk</td>
//       <td>female</td>
//       <td>white</td>
//       <td>.</td>
//       <td>.</td>
//       <td>26.2</td>
//     </tr>
//     <tr>
//       <th>14</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>male</td>
//       <td>black</td>
//       <td>15</td>
//       <td>45400</td>
//       <td>28.5</td>
//     </tr>
//     <tr>
//       <th>15</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>female</td>
//       <td>black</td>
//       <td>.</td>
//       <td>.</td>
//       <td>32</td>
//     </tr>
//   </tbody>
// </table>
// </div>

// %% [markdown]
// ### Specify which category to omit in regression
//
// Change the number in the stub of each nominal variable below to specify omitted categories

// %%
*ib* here tells Stata what category to omit 
reg realrinc i.sex i.race
// Out:
//       Source |       SS           df       MS      Number of obs   =     1,363
// -------------+----------------------------------   F(3, 1359)      =     25.23
//        Model |  5.9937e+10         3  1.9979e+10   Prob > F        =    0.0000
//     Residual |  1.0762e+12     1,359   791879153   R-squared       =    0.0528
// -------------+----------------------------------   Adj R-squared   =    0.0507
//        Total |  1.1361e+12     1,362   834141678   Root MSE        =     28140
//
// ------------------------------------------------------------------------------
//     realrinc | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//          sex |
//      female  |  -10329.82   1531.701    -6.74   0.000    -13334.58   -7325.067
//              |
//         race |
//       black  |  -8693.323   2073.471    -4.19   0.000    -12760.87   -4625.772
//       other  |  -8999.018   2353.323    -3.82   0.000    -13615.56   -4382.478
//              |
//        _cons |   32997.92   1201.363    27.47   0.000     30641.19    35354.65
// ------------------------------------------------------------------------------

// %% [markdown]
// ### A nice graphical way to represent dummy estimates is OLS adjusted means
//
// These are the estimated mean for a category if all other variables are estimated as held constant

// %%
%set graph_width = 11
// Out:
// graph size was (5.5in, 4in), is now (11, 4in).

// %%
%set graph_height = 8
// Out:
// graph size was (11, 4in), is now (11, 8).

// %%
set scheme plotplainblind
reg realrinc ib2.sex ib3.race
margins i.race, atmeans
*This will (quietly) run the regression again, then give 'margins'. 
// These are the regression adjusted averages for each category within 
//the requested variable. Margins can be considered a 'post estimation command'
// because we use it after doing a regression 

*marginsplot
// Out:
//       Source |       SS           df       MS      Number of obs   =     1,363
// -------------+----------------------------------   F(3, 1359)      =     25.23
//        Model |  5.9937e+10         3  1.9979e+10   Prob > F        =    0.0000
//     Residual |  1.0762e+12     1,359   791879153   R-squared       =    0.0528
// -------------+----------------------------------   Adj R-squared   =    0.0507
//        Total |  1.1361e+12     1,362   834141678   Root MSE        =     28140
//
// ------------------------------------------------------------------------------
//     realrinc | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//          sex |
//        male  |   10329.82   1531.701     6.74   0.000     7325.067    13334.58
//              |
//         race |
//       white  |   8999.018   2353.323     3.82   0.000     4382.478    13615.56
//       black  |   305.6956   2866.753     0.11   0.915    -5318.046    5929.437
//              |
//        _cons |   13669.08   2317.757     5.90   0.000     9122.313    18215.85
// ------------------------------------------------------------------------------
//
// Adjusted predictions                                     Number of obs = 1,363
// Model VCE: OLS
//
// Expression: Linear prediction, predict()
// At: 1.sex  = .4739545 (mean)
//     2.sex  = .5260455 (mean)
//     1.race = .7087307 (mean)
//     2.race = .1680117 (mean)
//     3.race = .1232575 (mean)
//
// ------------------------------------------------------------------------------
//              |            Delta-method
//              |     Margin   std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//         race |
//       white  |   27563.97   905.5441    30.44   0.000     25787.55    29340.38
//       black  |   18870.64   1864.152    10.12   0.000     15213.72    22527.57
//       other  |   18564.95   2172.757     8.54   0.000     14302.63    22827.27
// ------------------------------------------------------------------------------

// %%
marginsplot, unique recast(scatter) ytitle(estimated income)
* This then shows those margins. The `recast(scatter) piece 
// gets rid of the line between them, which makes sense since it 
// doesn't make sense to try and say that there is a linear 
//relationship between race. Unclear if `unique` is doing anything here
// Out:
// Variables that uniquely identify margins: race

// %%
set scheme plotplainblind
qui margins i.race, atmeans

// %% [markdown]
// ## 2. Recoding continuous variables to sequential dummies
//
// This is a good tool when interval ratio relationships change direction or slope (i.e. are non-linear)
//
// For example:
// * https://github.com/HigherEdData/Student-Debt-Cancellation-IS-Progressive/tree/main
// * student debt (DV) and parental income (IV) have a non-linear relationship (Houle 2014):
//
// ![image.png](attachment:image.png)
//
// ### What about modeling income (DV) and age (IV)?
//
// ### Is it linear?

// %%
tw (scatter realrinc age, sort) (lfit realrinc age, color(red) ///
lwidth(thick)), legend(off) name(linear, replace)

// %% [markdown]
// ### Convert age to sequential dummy variables to check
//
// First, recode age as age brackets

// %%
egen agecat = cut(age), at(18,30,40,50,60,70,90)
*This generates a variable that creates category
// ranges at the different places you say to cut it at. 
// Here, creates categories at different age ranges. 
sum agecat
tab agecat

// %%
codebook agecat
// Out:
// -------------------------------------------------------------------------------
// agecat                                                              (unlabeled)
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (float)
//
//                  Range: [18,70]                       Units: 1
//          Unique values: 6                         Missing .: 7/2,348
//
//             Tabulation: Freq.  Value
//                           398  18
//                           450  30
//                           365  40
//                           410  50
//                           361  60
//                           357  70
//                             7  .

// %% [markdown]
// ### Then regress income on age categories as dummies

// %%
xi: reg realrinc ib18.agecat i.sex i.race
// Out:
// i.sex             _Isex_1-2           (naturally coded; _Isex_1 omitted)
// i.race            _Irace_1-3          (naturally coded; _Irace_1 omitted)
//
//       Source |       SS           df       MS      Number of obs   =     1,358
// -------------+----------------------------------   F(8, 1349)      =     19.60
//        Model |  1.1820e+11         8  1.4775e+10   Prob > F        =    0.0000
//     Residual |  1.0170e+12     1,349   753882255   R-squared       =    0.1041
// -------------+----------------------------------   Adj R-squared   =    0.0988
//        Total |  1.1352e+12     1,357   836543033   Root MSE        =     27457
//
// ------------------------------------------------------------------------------
//     realrinc | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//       agecat |
//          30  |   11450.64   2332.097     4.91   0.000     6875.712    16025.57
//          40  |   17659.06   2450.147     7.21   0.000     12852.54    22465.57
//          50  |   19026.72   2378.168     8.00   0.000     14361.41    23692.02
//          60  |   14130.78   2795.609     5.05   0.000     8646.571       19615
//          70  |   11512.19   4100.657     2.81   0.005     3467.834    19556.55
//              |
//      _Isex_2 |  -10064.14   1498.695    -6.72   0.000    -13004.17   -7124.116
//     _Irace_2 |  -7582.115   2043.364    -3.71   0.000    -11590.63   -3573.599
//     _Irace_3 |   -8007.78    2322.14    -3.45   0.001    -12563.18   -3452.383
//        _cons |   19883.81   2040.571     9.74   0.000     15880.77    23886.85
// ------------------------------------------------------------------------------

// %%
%head
// Out:
// <div>
// <style scoped>
//     .dataframe tbody tr th:only-of-type {
//         vertical-align: middle;
//     }
//
//     .dataframe tbody tr th {
//         vertical-align: top;
//     }
//
//     .dataframe thead th {
//         text-align: right;
//     }
// </style>
// <table border="1" class="dataframe">
//   <thead>
//     <tr style="text-align: right;">
//       <th></th>
//       <th>age</th>
//       <th>educ</th>
//       <th>paeduc</th>
//       <th>sex</th>
//       <th>race</th>
//       <th>yearsjob</th>
//       <th>realrinc</th>
//       <th>PASEI10</th>
//       <th>agecat</th>
//       <th>_Isex_2</th>
//       <th>_Irace_2</th>
//       <th>_Irace_3</th>
//     </tr>
//   </thead>
//   <tbody>
//     <tr>
//       <th>1</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>male</td>
//       <td>white</td>
//       <td>1</td>
//       <td>.</td>
//       <td>58.4</td>
//       <td>40</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//     </tr>
//     <tr>
//       <th>2</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>female</td>
//       <td>white</td>
//       <td>.</td>
//       <td>.</td>
//       <td>24.6</td>
//       <td>70</td>
//       <td>1</td>
//       <td>0</td>
//       <td>0</td>
//     </tr>
//     <tr>
//       <th>3</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>male</td>
//       <td>white</td>
//       <td>15</td>
//       <td>45400</td>
//       <td>77.4</td>
//       <td>40</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//     </tr>
//     <tr>
//       <th>4</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>female</td>
//       <td>white</td>
//       <td>25</td>
//       <td>54480</td>
//       <td>67.7</td>
//       <td>60</td>
//       <td>1</td>
//       <td>0</td>
//       <td>0</td>
//     </tr>
//     <tr>
//       <th>5</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>male</td>
//       <td>black</td>
//       <td>.</td>
//       <td>.</td>
//       <td>58.4</td>
//       <td>70</td>
//       <td>0</td>
//       <td>1</td>
//       <td>0</td>
//     </tr>
//   </tbody>
// </table>
// </div>

// %%
*ib18 is treating agecat as a categorical variable and telling it to omit 18
*If you don't break down the age into categories and have an ommited, it
*doesn't understand that there is are categorical ranges for agecat. It treats is as a continuous variable
// treated it as linear, you would get a lower rsquared. This suggests that
// treating the relationship between age and the Y here as nonlinear has more explanatory value

qui margins i.agecat, atmeans
marginsplot, ytitle(estimated income)
// Out:
// Variables that uniquely identify margins: agecat

// %% [markdown]
// ## 3. Splines measure slopes of interval-ratio relationships that change
//
// *Splines measure the linear relationship for ranges of the IV.
//
// *This enables us to test changes at discrete breaking points.
//
// *ages1 for age-spline1 is set to the age for everyone under 50 and 50 for everyone above 50
// ages2 is set to the age minus 50 for everyone above 50 and 0 for everyone else

// %%
*Create two spline vars with a "Knot" at age 50
mkspline ages1 50 ages2 = age

*Look at the distribution of values for the two spline vars with histogram
histogram ages1, name(hist1)
histogram ages2, name(hist2)
// Out:
// (bin=33, start=18, width=.96969697)
// (bin=33, start=0, width=1.1818182)

// %%
list age ages1 ages2 if _n<9
// Out:
//       +---------------------+
//       | age   ages1   ages2 |
//       |---------------------|
//    1. |  43      43       0 |
//    2. |  74      50      24 |
//    3. |  42      42       0 |
//    4. |  63      50      13 |
//    5. |  71      50      21 |
//       |---------------------|
//    6. |  67      50      17 |
//    7. |  59      50       9 |
//    8. |  43      43       0 |
//       +---------------------+

// %%
*OLS estimate the slope for age above and below 50 and predict y values
regress realrinc ages1 ages2
drop yhat
predict yhat

*Graph the fited spline lines for ages above and below 50

tw (scatter realrinc age) (line yhat age, sort color(red) lwidth(thick))

*Below: showing that for every year under 50 you experience around 900 dollars increase in income.
//but after 50, your income goes down by nearly 500 dollars
// Out:
//       Source |       SS           df       MS      Number of obs   =     1,358
// -------------+----------------------------------   F(2, 1355)      =     45.15
//        Model |  7.0926e+10         2  3.5463e+10   Prob > F        =    0.0000
//     Residual |  1.0643e+12     1,355   785433845   R-squared       =    0.0625
// -------------+----------------------------------   Adj R-squared   =    0.0611
//        Total |  1.1352e+12     1,357   836543033   Root MSE        =     28026
//
// ------------------------------------------------------------------------------
//     realrinc | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        ages1 |   866.8012   93.33994     9.29   0.000     683.6947    1049.908
//        ages2 |  -463.5205   138.6246    -3.34   0.001    -735.4627   -191.5784
//        _cons |  -8611.677    3631.31    -2.37   0.018    -15735.28   -1488.077
// ------------------------------------------------------------------------------
// (option xb assumed; fitted values)
// (7 missing values generated)

// %% [markdown]
// ## 4. Quadratics: when interval ratio relationships gradually change direction
//
// * For example the relationship between income (DV) and age (IV)
// * The solution is to square the IV (age) and add it to the model:
//
// $ \hat{Y} = \alpha + \beta_1 \cdot X + \beta_2 \cdot X^2 $

// %% [markdown]
// ### Let's compare age coefficients with and w/o a quadratic
//
// Complete the code below to create a squared age variable

// %%
qui est clear

*Model 1 - no quadritic
qui eststo: regress realrinc age

*Model 2 - quadratic added
gen age2=age^2

qui eststo: regress realrinc age age2

list age age2 if _n<6
// Out:
// (7 missing values generated)
//
//       +------------+
//       | age   age2 |
//       |------------|
//    1. |  43   1849 |
//    2. |  74   5476 |
//    3. |  42   1764 |
//    4. |  63   3969 |
//    5. |  71   5041 |
//       +------------+

// %%
**Print a table with the two models
esttab, stats(r2 N, labels("R-Sqaured" "N")) cells(b(star fmt(3)) ///
se(fmt(3) par)) nobase

*age2 is negative because the extra high values of age start to have a negative effect.
// So the equation (above) will start to decrease somewhat for those values, despite age itself(if alone) being positive
// Out:
// --------------------------------------------
//                       (1)             (2)
//                  realrinc        realrinc
//                      b/se            b/se
// --------------------------------------------
// age               368.137***     2485.627***
//                  (53.864)       (316.065)
// age2                              -22.874***
//                                   (3.366)
// _cons            8620.324***   -35611.186***
//                (2516.285)      (6963.553)
// --------------------------------------------
// R-Sqaured           0.033           0.065
// N                1358.000        1358.000
// --------------------------------------------

// %% [markdown]
// ### Also graph the quadratic and compare

// %%
tw (scatter realrinc age, sort) ///
(lfit realrinc age, color(red) lwidth(thick)) ///
(qfit realrinc age, color(green) lwidth(thick)), ///
legend(off) name(quadratic, replace)

// %% [markdown]
// ## 5. Logarithms: model when interval ratio relationships accelerate/decelerate (curve)

// %% [markdown]
// ### Logs are a function that resemble relationships of diminishing returns. As x increase from zero to 5 at first, Y goes up a lot. But if x goes up from 5 to 10, Y does not increase as much.
//
// ### You can log dependent or independent
//
// *Some relationships curve, like with income (DV) and education/human capital investment (IV)
//
// *Logs are the opposites of exponents like $X^3$
//
// *Definition of (natural) logarithm: The exponent to which a another number (e=2.718... for natural logs) must be raised to produce X, Y, or any other given number. (e=2.718... is an irrational and transcendental number like $\pi$)
//
// $Z = ln(X)$ if $X = 2.718^Z$
//
// $ .30 = ln(2)$ if $2 = 2.718^z$
//
// *When graphed, the natural log function looks like this:

// %%
*Log is a particular shape, just like quadratic (above). You use
// it if you have an idea for what shape you think the relationship looks
tw (function Z = log(x), range(0 20))

// %% [markdown]
// **When X is less than 1 (like ..5), Z is negative
//
// We can reverse engineer this:

// %%
display "if Z=-2, X = 2.718^Z = 2.718^-2 = 1/2.718 * 1/2.718 = " 1/2.718 * 1/2.718
display "if X=.135, Z= ln(X) = ln(.135) = "log(.135)

display "if Z=2, X = 2.718^Z = 2.718^2 =  "= 2.718^2
display "if X=[??], Z= ln(X) = ln([??]) =" log(7.387524)
// Out:
// if Z=-2, X = 2.718^Z = 2.718^-2 = 1/2.718 * 1/2.718 = .13536335
// if X=.135, Z= ln(X) = ln(.135) = -2.0024805
// if Z=2, X = 2.718^Z = 2.718^2 = 7.387524
// if X=[??], Z= ln(X) = ln([??]) =1.9997926

// %% [markdown]
// ### A magical feature of logs:
//
// Logs approximate proportional change in the number that is logged for proportional chances less than .2 (20%).
//
// For example:

// %%
display "e^b = Proportional Change in X = X2/X1 = (110/100) = " 110/100
display "beta = ln(e^b) = nl(X2/X1) = nl(110/100) = " = log(11/10)
// Out:
// e^b = Proportional Change in X = X2/X1 = (110/100) = 1.1
// beta = ln(e^b) = nl(X2/X1) = nl(110/100) = .09531018

// %% [markdown]
// ### Let's apply this to income (DV) and education (IV)
//
// *First, create a new variable that logs income
//
// *Then regress the unlogged and logged income variable (DV) on education (IV) and compare
//
// *Which estimates are better and why? What is the proportional increase for income for every year of education?

// %%
**Create a logged income variable
gen realrinc_ln=log(realrinc)

// %%
qui est clear

**Regress w/o logging
qui eststo: reg realrinc educ

** Predict Y-hat based on the above regression

predict ytest, xb
// Out:
// variable ytest already defined
// r(110);

// %%
**Regress logged Y on education
qui eststo: reg realrinc_ln educ

** Predict logged Y-hat based on the above regression
predict Ytestln
// Out:
// (option xb assumed; fitted values)
// (3 missing values generated)

// %%
%head if _n<6
// Out:
// <div>
// <style scoped>
//     .dataframe tbody tr th:only-of-type {
//         vertical-align: middle;
//     }
//
//     .dataframe tbody tr th {
//         vertical-align: top;
//     }
//
//     .dataframe thead th {
//         text-align: right;
//     }
// </style>
// <table border="1" class="dataframe">
//   <thead>
//     <tr style="text-align: right;">
//       <th></th>
//       <th>age</th>
//       <th>educ</th>
//       <th>paeduc</th>
//       <th>sex</th>
//       <th>race</th>
//       <th>yearsjob</th>
//       <th>realrinc</th>
//       <th>PASEI10</th>
//       <th>agecat</th>
//       <th>_Isex_2</th>
//       <th>_Irace_2</th>
//       <th>_Irace_3</th>
//       <th>ages1</th>
//       <th>ages2</th>
//       <th>realrinc_ln</th>
//       <th>yhat</th>
//       <th>yhatln</th>
//       <th>ytest</th>
//       <th>_est_est1</th>
//       <th>_est_est2</th>
//       <th>_est_est3</th>
//       <th>Ytestln</th>
//     </tr>
//   </thead>
//   <tbody>
//     <tr>
//       <th>1</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>male</td>
//       <td>white</td>
//       <td>1</td>
//       <td>.</td>
//       <td>58.4</td>
//       <td>40</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>43</td>
//       <td>0</td>
//       <td>.</td>
//       <td>24592.95</td>
//       <td>9.537351</td>
//       <td>24592.95</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>9.537351</td>
//     </tr>
//     <tr>
//       <th>2</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>female</td>
//       <td>white</td>
//       <td>.</td>
//       <td>.</td>
//       <td>24.6</td>
//       <td>70</td>
//       <td>1</td>
//       <td>0</td>
//       <td>0</td>
//       <td>50</td>
//       <td>24</td>
//       <td>.</td>
//       <td>12107.58</td>
//       <td>8.953649</td>
//       <td>12107.58</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>8.953649</td>
//     </tr>
//     <tr>
//       <th>3</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>male</td>
//       <td>white</td>
//       <td>15</td>
//       <td>45400</td>
//       <td>77.4</td>
//       <td>40</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>42</td>
//       <td>0</td>
//       <td>10.72327</td>
//       <td>30835.63</td>
//       <td>9.829202</td>
//       <td>30835.63</td>
//       <td>1</td>
//       <td>1</td>
//       <td>1</td>
//       <td>9.829202</td>
//     </tr>
//     <tr>
//       <th>4</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>female</td>
//       <td>white</td>
//       <td>25</td>
//       <td>54480</td>
//       <td>67.7</td>
//       <td>60</td>
//       <td>1</td>
//       <td>0</td>
//       <td>0</td>
//       <td>50</td>
//       <td>13</td>
//       <td>10.90559</td>
//       <td>30835.63</td>
//       <td>9.829202</td>
//       <td>30835.63</td>
//       <td>1</td>
//       <td>1</td>
//       <td>1</td>
//       <td>9.829202</td>
//     </tr>
//     <tr>
//       <th>5</th>
//       <td></td>
//       <td></td>
//       <td></td>
//       <td>male</td>
//       <td>black</td>
//       <td>.</td>
//       <td>.</td>
//       <td>58.4</td>
//       <td>70</td>
//       <td>0</td>
//       <td>1</td>
//       <td>0</td>
//       <td>50</td>
//       <td>21</td>
//       <td>.</td>
//       <td>37078.31</td>
//       <td>10.12105</td>
//       <td>37078.31</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>10.12105</td>
//     </tr>
//   </tbody>
// </table>
// </div>

// %%
**Then exponentiate 
replace yhatln=2.718^(yhatln)

eststo 

**Print estimates from both models
esttab, stats(r2 N, labels("R-Sqaured" "N")) cells(b(star fmt(3)) ///
se(fmt(3) par)) nobase
// Out:
// (2,345 real changes made)
//
// ------------------------------------------------------------
//                       (1)             (2)             (3)
//                  realrinc     realrinc_ln     realrinc_ln
//                      b/se            b/se            b/se
// ------------------------------------------------------------
// educ             3121.341***        0.146***        0.146***
//                 (261.385)         (0.011)         (0.011)
// _cons          -19105.831***        7.494***        7.494***
//                (3768.318)         (0.160)         (0.160)
// ------------------------------------------------------------
// R-Sqaured           0.095           0.113           0.113
// N                1362.000        1362.000        1362.000
// ------------------------------------------------------------

// %% [markdown]
// ### The logged results can be more intuitive when graphed

// %%
**Create a scatterplot of income and education
**with fitted linear regression line and fitted logged regression line
tw (scatter realrinc educ if realrinc<50000) ///
(line yhat educ, sort color(red) lwidth(thick)) ///
(line yhatln educ, sort color(blue) lwidth(thick)), legend(off)

// %% [markdown]
// You may want to run correlation analysis to see the linear relationship among variables
