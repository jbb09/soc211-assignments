// %% [markdown]
// # Research assignment 3
//
// Anh Nguyen Tran
//
// Is the "Fatherhood Bonus" Real?: Discrimination against Child-Free Men in the Workplace
//
// 02/21/2024

// %% [markdown]
// ## 1. Build your hypothesis
//
// Write bullet points that answer the following questions:
//
//     A. What is your dependent variable? For this assignment, your dependent should be a continuous variable. Describe how your dependent variable is measured. If your data doesn't allow this, you can use either the General Social Survey 2018 or the Grant and Loan Repayment data.
//
//     ---
//
//     EXAMPLE ANSWER: My dependent variable is income. My dependent variable is a continuous variable that ranges from 500 to 50000 and is measured in dollars. I recoded the variable from GSS representing the respondent's income from nominal to continuous using the midpoint formula on the income categories.
//
//     ---
//
//     B. What are the independent variables you are most interested in? Are they interval ratio or nominal? Why?
//
//     ---
//
//     EXAMPLE ANSWER: My independent variables of interest are the following: fatherhood and marital status. Both variables are nominal. I am interested in examining fatherhood status because research shows that there is discrimination against childfree men in the workplace, with fathers receiving more promotions and earning higher incomes due to this bias against childfree men. In addition, there is research showing that single (not married) people, including men, are discriminated against as well in the workplace. I am focused on men who are working full-time in the traditional workforce for this project.
//
//     ---
//
//     C. What are your control variables? Are they interval ratio or nominal? Why?
//
//     ---
//
//     EXAMPLE ANSWER: My control variables are age, education, and race. Age and education are interval-ratio variables, while race is a nominal variable. I include age because age may be a spurious factor. In other words, there may appear to be discrimination against childfree men, but this discrimination might disappear if age is controlled for. After all, working men without children tend to be younger than working fathers. Education, which is a huge causal factor for how much income an individual makes, is a possibly intervening factor, with working fathers who are married being more likely to have higher education because they have spouses that could support them in their educational attainment. Race is included as a control variable as well because racial discrimination, which determines in part the amount of education one receives and has a separate effect on income as well, exists in the workplace and thus, is an interactive factor to consider.
//
//     ---
//
//     D. What are your hypotheses on the relationships between your dependent and independent variables (including control variables)? Make seperate hypotheses for separate independent variables and for intervening relationships that involve multiple independent variables of interest.
//
//     ---
//
//     EXAMPLE HYPOTHESES:
//     H1: I hypothesize that working fathers with children have higher incomes than working men without children.
//
//     H2: I hypothesize that working fathers with children have higher incomes than working men without children when the fathers are married and the working men are single (not married).
//
//     H3: I hypothesize that working fathers with children have higher incomes than working men without children when the fathers are married and the working men are single (not married), controlling for age, education, and race.

// %% [markdown]
// ## 2. Prepare your data
//
// Do the following:
//
//     A. Set current directory
//
//     B. Set more off
//
//     C. Creat log file
//
//     D. Load only variable from the dataset that you will use
//
//     E. Use -describe- and -codebook- to see details of the variables

// %%
cd "/Users/anhnguyentran/Desktop/GradStats2_Lab"
// Out:
// <style>div.jp-Notebook .datagrid-container {min-height: 448px; }</style>
// /Users/anhnguyentran/Desktop/GradStats2_Lab

// %%
set more off
// Out:
// (-set more- irrelevant in this version of Stata)

// %%
log using "Research Assignment 3.log", replace
// Out:
// -------------------------------------------------------------------------------
//       name:  <unnamed>
//        log:  /Users/anhnguyentran/Desktop/GradStats2_Lab/Research Assignment 3.
// > log
//   log type:  text
//  opened on:  21 Feb 2024, 23:33:11

// %%
use id year rincome sex wrkstat childs marital age educ race using "gss7222_r2 copy.dta", clear

// %%
describe
// Out:
// Contains data from gss7222_r2 copy.dta
//  Observations:        72,390
//     Variables:            10                  11 Jan 2024 10:13
// -------------------------------------------------------------------------------
// Variable      Storage   Display    Value
//     name         type    format    label      Variable label
// -------------------------------------------------------------------------------
// year            int     %29.0g     COUNTMISS
//                                               gss year for this respondent
// id              int     %8.0g                 respondent id number
// wrkstat         byte    %74.0g     WRKSTAT    labor force status
// marital         byte    %29.0g     MARITAL    marital status
// childs          byte    %29.0g     NUM8F      number of children
// age             byte    %29.0g     AGE        age of respondent
// educ            byte    %29.0g     EDUC       highest year of school completed
// ...

// %%
codebook rincome wrkstat marital childs age educ sex race
// Out:
// -------------------------------------------------------------------------------
// rincome                                                      respondents income
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: INCOME
//
//                  Range: [1,12]                        Units: 1
//          Unique values: 12                        Missing .: 0/72,390
//        Unique mv codes: 5                        Missing .*: 30,057/72,390
//
//               Examples: 9     $10,000 to $14,999
//                         12    $25,000 or more
//                         .i    iap
//                         .i    iap
//
// -------------------------------------------------------------------------------
// wrkstat                                                      labor force status
// -------------------------------------------------------------------------------
//
// ...

// %%
tab rincome
tab rincome, nol
// Out:
//            respondents income |      Freq.     Percent        Cum.
// ------------------------------+-----------------------------------
//                  under $1,000 |      1,365        3.22        3.22
//              $1,000 to $2,999 |      1,952        4.61        7.84
//              $3,000 to $3,999 |      1,300        3.07       10.91
//              $4,000 to $4,999 |      1,099        2.60       13.50
//              $5,000 to $5,999 |      1,149        2.71       16.22
//              $6,000 to $6,999 |      1,037        2.45       18.67
//              $7,000 to $7,999 |      1,031        2.44       21.10
//              $8,000 to $9,999 |      1,840        4.35       25.45
//            $10,000 to $14,999 |      5,138       12.14       37.59
//            $15,000 to $19,999 |      4,048        9.56       47.15
//            $20,000 to $24,999 |      4,125        9.74       56.89
//               $25,000 or more |     18,249       43.11      100.00
// ...

// %%
*Turning income into a continuous variable by using the midpoint
gen income=.
replace income=500 if rincome==1
replace income=2000 if rincome==2
replace income=3500 if rincome==3
replace income=4500 if rincome==4
replace income=5500 if rincome==5
replace income=6500 if rincome==6
replace income=7500 if rincome==7
replace income=9000 if rincome==8
replace income=12500 if rincome==9
replace income=17500 if rincome==10
replace income=22500 if rincome==11
replace income=50000 if rincome==12
// Out:
// (72,390 missing values generated)
// (1,365 real changes made)
// (1,952 real changes made)
// (1,300 real changes made)
// (1,099 real changes made)
// (1,149 real changes made)
// (1,037 real changes made)
// (1,031 real changes made)
// (1,840 real changes made)
// (5,138 real changes made)
// (4,048 real changes made)
// (4,125 real changes made)
// (18,249 real changes made)

// %%
label variable income "amount of income respondent makes (dollars)"
tab income
// Out:
//   amount of |
//      income |
//  respondent |
//       makes |
//   (dollars) |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//         500 |      1,365        3.22        3.22
//        2000 |      1,952        4.61        7.84
//        3500 |      1,300        3.07       10.91
//        4500 |      1,099        2.60       13.50
//        5500 |      1,149        2.71       16.22
//        6500 |      1,037        2.45       18.67
//        7500 |      1,031        2.44       21.10
//        9000 |      1,840        4.35       25.45
//       12500 |      5,138       12.14       37.59
//       17500 |      4,048        9.56       47.15
//       22500 |      4,125        9.74       56.89
//       50000 |     18,249       43.11      100.00
// ------------+-----------------------------------
//       Total |     42,333      100.00

// %%
*Keeping only respondents who are men and who are currently employed/working full-time
drop if sex==2
drop if wrkstat!=1
// Out:
// (40,301 observations deleted)
// (12,589 observations deleted)

// %%
*Creating a dummy variable for if the man has a child or not
gen father=.
replace father=0 if childs==0
replace father=1 if childs>0

label variable father "the respondent is a father"
tab father
// Out:
// (19,500 missing values generated)
// (6,198 real changes made)
// (13,302 real changes made)
//
//         the |
//  respondent |
// is a father |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |      6,198       31.78       31.78
//           1 |     13,302       68.22      100.00
// ------------+-----------------------------------
//       Total |     19,500      100.00

// %%
*Creating a dummy variable for if the man is currently married or not
gen married=.
replace married=0 if marital!=1
replace married=1 if marital==1

label variable married "the respondent is married"
tab married
// Out:
// (19,500 missing values generated)
// (7,470 real changes made)
// (12,030 real changes made)
//
//         the |
//  respondent |
//  is married |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |      7,470       38.31       38.31
//           1 |     12,030       61.69      100.00
// ------------+-----------------------------------
//       Total |     19,500      100.00

// %% [markdown]
// ## 3. Use scatterplots to visually assess relationships between your dependent variable and all of your independent variables
//
//     A. Quietly generate scatterplots for the dependent variable and each independent variable (including control variables). Then use graph combine to examine all of the scatter plots.
//
//     B. Write a paragraph interpreting what the scatterplots show
//
//     ---
//
//     EXAMPLE ANSWER: The scatterplots represent the bivariate relationship between income and each independent variables. There appears to be a moderately positive association between age and education with income. There is a slight positive association between fatherhood and marital status with income. The fitted line for race is relatively flat, indicating there may be no association between race and income.

// %%
*Use a loop command for all of the variables

foreach x in father married age educ race {
quietly  graph twoway (scatter income `x') (lfit income `x', color(red)), ///
    name(`x', replace) legend(off) ytitle(income) scheme(plotplainblind)
}

// %%
%set graph_width = 11
// Out:
// graph size was (5.5in, 4in), is now (11, 4in).

// %%
%set graph_height = 8
// Out:
// graph size was (11, 4in), is now (11, 8).

// %%
graph combine father married age educ race, col(3) scheme(plotplainblind) xsize(4)

// %% [markdown]
// ## 4. Assess multicorrelation among your independent variables
//
//     A. Create a correlation matrix for all of your variables.
//
//     B. Write bullet points or a short paragraph summarizing what the matrix shows.
//
//     ---
//
//     NOTE FROM ANH: The closer to 1 that a number is, the stronger the correlation between the two variables. The closer to 0 that a number is, the weaker the correlation between the two variables.
//
//     GENERAL RULE OF THUMB: Anything above 0.5 is a strong correlation. Anything between 0.2-0.5 is a moderate correlation. Anything under a 0.2 is a weak/negligible correlation.
//
//     ---
//
//     EXAMPLE ANSWER: As indicated by the scatterplots, there are moderate positive correlations between age and education with income and weak positive correlations between father and marital status with income. The correlation between race and income is  negligible, also shown by the scatterplot.
//
//     Regarding the relationships between independent variables, there are moderate, positive correlations between being married and being a father and being older and being a father. These respective independent variables may be interacting with one another. The other independent variables are negligibly correlated with each other.

// %%
*pwcorr gives you the correlation matrix using listwise deletion (do not use correlate- correlate will use all of the data)

pwcorr income father married age educ race
// Out:
//              |   income   father  married      age     educ     race
// -------------+------------------------------------------------------
//       income |   1.0000
//       father |   0.1035   1.0000
//      married |   0.0714   0.4528   1.0000
//          age |   0.2541   0.3576   0.2177   1.0000
//         educ |   0.3353  -0.1083  -0.0086   0.0076   1.0000
//         race |  -0.0118   0.0169  -0.0815  -0.0519  -0.0798   1.0000

// %% [markdown]
// ## 5. Describe at least 2 OLS models to test your hypotheses
//
// Write a paragraph or a set of bullet points that explain:
//
//     A. Which model tests which of your hypotheses
//
//     ---
//
//     EXAMPLE ANSWER:
//
//     Model 1: H1
//     Model 2: H2
//     Model 3: H3
//
//     ---
//
//     B. Which variables are included in each model
//
//     ---
//
//     EXAMPLE ANSWER:
//
//     All models have income as their dependent variable.
//
//     Model 1: Fatherhood status
//     Model 2: Fatherhood and marital status
//     Model 3: Fatherhood and marital status with age, education, and race controlled for
//
//     ---
//
//     B. How/why adding particular variables to subsequent models will test for spurious or intervening relationships
//
//     ---
//
//     EXAMPLE ANSWER:
//
//     Model 1 tests the main hypothesis I am interested in concerning discrimination against childfree men. Model 2 includes marital status as another social factor of interest, which is indicated to be strongly associated with fatherhood status. Including marital status may reduce any potential association between fatherhood status and income; however, marital status is another potential source of income disparity that is also important to study. Model 3 includes age, education, and race as controls. I am not as interested in these variables, so I am putting these variables all in at the same time to see if my findings for Model 1 and Model 2 are robust.

// %% [markdown]
// ## 6. Write OLS regression equations for each model
//
// Use subscripts to indicate which symbols represesent your different independent variables. To do so, you can copy and paste the LaTex code in this week's lesson notebook and edit the subscripts.
//
// ---
//
// NOTE: Anh got lazy here- but YOU have to make equations for EACH model.
//
// ---
//
// MODEL 3:
//
// #### $\hat{Y} = \alpha + \beta_f \cdot x_f + \beta_m \cdot x_m + \beta_a \cdot x_a + \beta_e \cdot x_e + \beta_b \cdot x_b + \beta_o \cdot x_o $
//
// $\hat{Y}$ is the respondent's income
//
// $\alpha$ is the intercept term
//
// $x_f$ is fatherhood status
//
// $x_m$ is marital status
//
// $x_a$ is age
//
// $x_b$ is Black respondents
//
// $x_o$ is other race respondents

// %% [markdown]
// ## 7. Estimate your models with stata
//
//     A. Write Stata code to estimate the models and store the regression results
//
//     B. Write code to output the estimates in a table within Jupyter Notebook and as an RTF file

// %%
est clear

*Model 1
quietly eststo: reg income father

*Model 2
quietly eststo: reg income father married

*Model 3
quietly eststo: reg income father married age educ i.race

// %%
*Run one esttab to show the output within Jupyter Notebook

esttab, stats(r2 N, labels("R-Squared" "N")) cells(b(star fmt(3)) se(fmt(3) par)) /// 
  nobase mlabels ("Model 1" "Model 2" "Model 3") starlevels(* .05 ** .01 *** .001) ///
  coeflabels (educ "education" 2.race "black" 3.race "other race") noconstant
// Out:
// ------------------------------------------------------------
//                       (1)             (2)             (3)
//                   Model 1         Model 2         Model 3
//                      b/se            b/se            b/se
// ------------------------------------------------------------
// father           3981.328***     3442.126***     2356.851***
//                 (297.528)       (332.376)       (322.011)
// married                          1156.067***     -304.106
//                                 (318.130)       (294.057)
// age                                               335.399***
//                                                  (11.101)
// education                                        1985.264***
//                                                  (42.112)
// black                                           -2370.538***
//                                                 (418.734)
// other race                                       3370.201***
// ...

// %%
*Run another esttab to store the table as an RTF file now

quietly esttab using researchassignment3_tables.rtf, stats(r2 N, labels("R-Squared" "N")) cells(b(star fmt(3)) se(fmt(3) par)) /// 
  nobase mlabels ("Model 1" "Model 2" "Model 3") starlevels(* .05 ** .01 *** .001) ///
  coeflabels (educ "education" 2.race "black" 3.race "other race") noconstant rtf replace

// %% [markdown]
// ## 8. Summarize the results for your hypotheses
//
//     A. Which of your hypotheses are supported and which are rejected by the (in)consistency of coefficients across all of your models?
//
//     ---
//
//     EXAMPLE ANSWER: Working men who are fathers have higher incomes than working men who are not fathers. Fatherhood status is statistically significant for income across all models (p < 0.001). In other words, this finding holds true even when marital status, age, education, and race are included in the analysis. In summary, the relationship between fatherhood status and income is not spurious.
//
//     There is some evidence for hypothesis 1 and hypothesis 2. Hypothesis 3 is only partially supported by the findings, as marital status is no longer statistically significant in Model 3.
//
//     ---
//
//     B. Which of your hypotheses regarding intervening or spurious relationships are supported / rejected by similarities / differences in coefficients across all of your models?
//
//     ---
//
//     EXAMPLE ANSWER: In Model 2, both fatherhood and marital status are statistically significant for income (p < 0.001). This provides some evidence that marital status, separate from fatherhood status, holds some influence over income. However, there appears to be no relationship between marital status and income when age, education, and race are controlled for. This suggests that marital status is not important on its own; marital status may be acting as a proxy for another factor that influences income.
//
//     Age, education, and race are all statistically significant in Model 3. Age and education are positively associated with income. Essentially, men who are older and who are more educated have higher incomes. Furthermore, Black men have lower incomes compared to white men, where as other race individuals have higher incomes compared to white men. While these control variables appear to play some role in income, fatherhood status remains significant with the inclusion of these controls, indicating that there may indeed be discrimination against childfree men occurring. My findings provide some evidence that the "fatherhood bonus" is real.
//
//     ---
//
//     C. What ideas do you have for why any of your hypotheses were rejected? Are there additional omitted variables do you think you should include to test your hypotheses that might change your results? Why?
//
//     ---
//
//     NOTE FROM ANH: There is no wrong answer here. Think about the larger world! :) For instance, maybe class plays a role in. Rich and middle-class guys (aka guys born to rich parents) are more likely to get married. They are also more likely to be white and educated. Maybe class is a missing factor that I should have considered in my analysis!

// %%
log close
// Out:
//       name:  <unnamed>
//        log:  /Users/anhnguyentran/Desktop/GradStats2_Lab/Research Assignment 3.
// > log
//   log type:  text
//  closed on:  21 Feb 2024, 23:33:33
// -------------------------------------------------------------------------------
