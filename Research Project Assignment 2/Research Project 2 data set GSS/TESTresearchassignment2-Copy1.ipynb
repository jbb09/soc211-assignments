// %% [markdown]
// ## Research assignment 2
//
// [your name]
//
// [working title of the project]
//
// [date]

// %% [markdown]
// ### 1. Write a paragraph about your hypotheses
//
// [Your answer here should explain:
// 1. What are your dependent variables? Why do they interest you?
// 2. What are your independent variables? What direction to you hypothesize will be the relationship between your dependent variable and your dependent variables?
// 3. Why do you think your dependent variables are associated with your independent variables?
// 4. What are your control variables? Do you think they will show any spurious, intervening, or interactive relationships? Why?]

// %% [markdown]
// ### 1. Setting up your session
//
// In the code cell below, do the following:
//
// 1. set current directory
// 2. set more off
// 3. create log file
// 4. download the data from its source if it's available online
// 5. read the data in [preferably only variables you are going to use]

// %%
cd "C:\Users\User\Documents\GRAD STATS LAB SEM 2\Soc211 Assignments\Research Project Assignment 2"
// Out:
// <style>div.jp-Notebook .datagrid-container {min-height: 448px; }</style>
// C:\Users\User\Documents\GRAD STATS LAB SEM 2\Soc211 Assignments\Research Projec
// > t Assignment 2

// %%
set more off
// Out:
// (-set more- irrelevant in this version of Stata)

// %%
log using "Research_Project_2.log", replace
// Out:
// -------------------------------------------------------------------------------
//       name:  <unnamed>
//        log:  C:\Users\User\Documents\GRAD STATS LAB SEM 2\Soc211 Assignments\Re
// > search Project Assignment 2\Research_Project_2.log
//   log type:  text
//  opened on:   8 Feb 2024, 12:21:41

// %%
use "C:\Users\User\Documents\GRAD STATS LAB SEM 2\Soc211 Assignments\Research Project Assignment 2\Research Project 2 data set GSS\GSS.dat", clear
// Out:
// file C:\Users\User\Documents\GRAD STATS LAB SEM 2\Soc211 Assignments\Research
//     Project Assignment 2\Research Project 2 data set GSS\GSS.dat not Stata
//     format
// r(610);

// %%
%head
// Out:
// <div>
// <style scoped>
//     .dataframe tbody tr th:only-of-type {
//         vertical-align: middle;
//     }
//
//     .dataframe tbody tr th {
//         vertical-align: top;
//     }
//
//     .dataframe thead th {
//         text-align: right;
//     }
// </style>
// <table border="1" class="dataframe">
//   <thead>
//     <tr style="text-align: right;">
//       <th></th>
//       <th>v1</th>
//     </tr>
//   </thead>
//   <tbody>
//     <tr>
//       <th>1</th>
//       <td>16   3 -100 -100    1 -100 -100 -100 -100 -10...</td>
//     </tr>
//     <tr>
//       <th>2</th>
//       <td>10   0 -100 -100    1 -100 -100 -100 -100 -10...</td>
//     </tr>
//     <tr>
//       <th>3</th>
//       <td>12   1 -100 -100    1 -100 -100 -100 -100 -10...</td>
//     </tr>
//     <tr>
//       <th>4</th>
//       <td>17   3 -100 -100    1 -100 -100 -100 -100 -10...</td>
//     </tr>
//     <tr>
//       <th>5</th>
//       <td>12   1 -100 -100    1 -100 -100 -100 -100 -10...</td>
//     </tr>
//   </tbody>
// </table>
// </div>

// %%
tab C
// Out:
//                 C |      Freq.     Percent        Cum.
// ------------------+-----------------------------------
//          Alameda  |        360        4.48        4.48
//           Alpine  |          1        0.01        4.49
//           Amador  |          9        0.11        4.60
//            Butte  |         51        0.63        5.24
//        Calaveras  |         10        0.12        5.36
// California County |          1        0.01        5.38
//           Colusa  |          5        0.06        5.44
//      Contra Costa |        207        2.58        8.01
//         Del Norte |          7        0.09        8.10
//         El Dorado |         42        0.52        8.62
//           Fresno  |        199        2.48       11.10
//            Glenn  |          6        0.07       11.17
//         Humboldt  |         30        0.37       11.55
//         Imperial  |         31        0.39       11.93
//             Inyo  |          6        0.07       12.01
//             Kern  |        151        1.88       13.89
//            Kings  |         27        0.34       14.22
//             Lake  |         15        0.19       14.41
//           Lassen  |          9        0.11       14.52
//       Los Angeles |      2,343       29.16       43.68
//           Madera  |         23        0.29       43.96
//            Marin  |         55        0.68       44.65
//         Mariposa  |          6        0.07       44.72
//        Mendocino  |         20        0.25       44.97
//           Merced  |         49        0.61       45.58
//            Modoc  |          4        0.05       45.63
//             Mono  |          3        0.04       45.67
//         Monterey  |         93        1.16       46.83
//             Napa  |         40        0.50       47.32
//           Nevada  |         20        0.25       47.57
//           Orange  |        582        7.24       54.82
//           Placer  |         84        1.05       55.86
//           Plumas  |          7        0.09       55.95
//        Riverside  |        453        5.64       61.59
//       Sacramento  |        317        3.94       65.53
//        San Benito |         11        0.14       65.67
//    San Bernardino |        369        4.59       70.26
//         San Diego |        627        7.80       78.06
//     San Francisco |        195        2.43       80.49
//       San Joaquin |        139        1.73       82.22
//   San Luis Obispo |         53        0.66       82.88
//         San Mateo |        157        1.95       84.83
//     Santa Barbara |         89        1.11       85.94
//       Santa Clara |        372        4.63       90.57
//        Santa Cruz |         52        0.65       91.21
//           Shasta  |         48        0.60       91.81
//           Sierra  |          1        0.01       91.82
//         Siskiyou  |         14        0.17       92.00
//           Solano  |         96        1.19       93.19
//           Sonoma  |         99        1.23       94.43
//       Stanislaus  |         94        1.17       95.59
//           Sutter  |         21        0.26       95.86
//           Tehama  |         11        0.14       95.99
//          Trinity  |          5        0.06       96.06
//           Tulare  |         78        0.97       97.03
//         Tuolumne  |         11        0.14       97.16
//          Ventura  |        173        2.15       99.32
//             Yolo  |         41        0.51       99.83
//             Yuba  |         14        0.17      100.00
// ------------------+-----------------------------------
//             Total |      8,036      100.00

// %% [markdown]
// ### 2. Browse the data
//
// Do the following in separate cells. Do do these in separate cells, you will need to use the right click "split cell" option:
//
// 1. Use "describe" to print details about the dataset
// 2. Print the heads and tables of the data using the appropriate magic
// 3. label the unique identifier variable
// 4. Generate a frequency table to show the N for each unit of time if there is data for multiple units in time
// 5. Check for missing data overall and within key categories of analysis (time, independent or dependent variable categories, etc)
// 6. use summarize to create a table with summary statistics for each variable you plan to analyze

// %%
*Use "describe" to print details about the dataset

describe
// Out:
// Contains data
//  Observations:         8,036
//     Variables:            58
// -------------------------------------------------------------------------------
// Variable      Storage   Display    Value
//     name         type    format    label      Variable label
// -------------------------------------------------------------------------------
// A               str12   %12s
// B               str16   %16s
// C               str17   %17s
// D               str5    %9s
// E               str42   %42s
// F               str12   %12s
// G               str10   %10s
// H               str17   %17s
// I               str18   %18s
// J               str24   %24s
// K               str9    %9s
// L               str17   %17s
// M               str17   %17s
// N               str17   %17s
// O               str17   %17s
// P               str17   %17s
// Q               str17   %17s
// R               str19   %19s
// S               str17   %17s
// T               str17   %17s
// U               str17   %17s
// V               str17   %17s
// W               str17   %17s
// X               str17   %17s
// Y               str17   %17s
// Z               str17   %17s
// AA              str17   %17s
// AB              str18   %18s
// AC              str19   %19s
// AD              str24   %24s
// AE              str17   %17s
// AF              str17   %17s
// AG              str17   %17s
// AH              str22   %22s
// AI              str17   %17s
// AJ              str17   %17s
// AK              str17   %17s
// AL              str22   %22s
// AM              str21   %21s
// AN              str17   %17s
// AO              str17   %17s
// AP              str17   %17s
// AQ              str21   %21s
// AR              str22   %22s
// AS              str27   %27s
// AT              str17   %17s
// AU              str17   %17s
// AV              str20   %20s
// AW              str25   %25s
// AX              str17   %17s
// AY              str17   %17s
// AZ              str17   %17s
// BA              str17   %17s
// BB              str17   %17s
// BC              str19   %19s
// BD              str17   %17s
// BE              str17   %17s
// BF              str17   %17s
// -------------------------------------------------------------------------------
// Sorted by:
//      Note: Dataset has changed since last saved.

// %%
*renaming variables when excel just gives you the column letter
rename A census_tract

// %%
*getting rid of the 1st row which gives the variable names. Since Stata doesn't recognize, only useful to tell you what to rename the variables to. Probably want to run at the end to clear them out once you don't need them 
drop if census_tract=="Census Tract"
// Out:
// (1 observation deleted)

// %%
*Print the heads and tables of the data using the appropriate magic(below)

// %%
%head
// Out:
// <div>
// <style scoped>
//     .dataframe tbody tr th:only-of-type {
//         vertical-align: middle;
//     }
//
//     .dataframe tbody tr th {
//         vertical-align: top;
//     }
//
//     .dataframe thead th {
//         text-align: right;
//     }
// </style>
// <table border="1" class="dataframe">
//   <thead>
//     <tr style="text-align: right;">
//       <th></th>
//       <th>census_tract</th>
//       <th>B</th>
//       <th>C</th>
//       <th>D</th>
//       <th>E</th>
//       <th>F</th>
//       <th>G</th>
//       <th>H</th>
//       <th>I</th>
//       <th>J</th>
//       <th>K</th>
//       <th>L</th>
//       <th>M</th>
//       <th>N</th>
//       <th>O</th>
//       <th>P</th>
//       <th>Q</th>
//       <th>R</th>
//       <th>S</th>
//       <th>T</th>
//       <th>U</th>
//       <th>V</th>
//       <th>W</th>
//       <th>X</th>
//       <th>Y</th>
//       <th>Z</th>
//       <th>AA</th>
//       <th>AB</th>
//       <th>AC</th>
//       <th>AD</th>
//       <th>AE</th>
//       <th>AF</th>
//       <th>AG</th>
//       <th>AH</th>
//       <th>AI</th>
//       <th>AJ</th>
//       <th>AK</th>
//       <th>AL</th>
//       <th>AM</th>
//       <th>AN</th>
//       <th>AO</th>
//       <th>AP</th>
//       <th>AQ</th>
//       <th>AR</th>
//       <th>AS</th>
//       <th>AT</th>
//       <th>AU</th>
//       <th>AV</th>
//       <th>AW</th>
//       <th>AX</th>
//       <th>AY</th>
//       <th>AZ</th>
//       <th>BA</th>
//       <th>BB</th>
//       <th>BC</th>
//       <th>BD</th>
//       <th>BE</th>
//       <th>BF</th>
//     </tr>
//   </thead>
//   <tbody>
//     <tr>
//       <th>1</th>
//       <td>6019001100</td>
//       <td>2780</td>
//       <td>Fresno</td>
//       <td>93706</td>
//       <td>Fresno</td>
//       <td>-119.7816961</td>
//       <td>36.7096952</td>
//       <td>93.18356973193831</td>
td>
//       <td>NA</td>
//       <td>NA</td>
//       <td>.266487859</td>
//       <td>33.2068965517241</td>
//       <td>376.508667</td>
//       <td>45.9114778694674</td>
//       <td>2406.694437</td>
//       <td>91.6875</td>
//       <td>.1</td>
//       <td>2.07166853303471</td>
//       <td>.3</td>
//       <td>2.10858376224473</td>
//       <td>.21</td>
//       <td>37.6836532097948</td>
//       <td>4</td>
//       <td>43.7841243175137</td>
//       <td>0</td>
//       <td>0</td>
//       <td>44.0322921513731</td>
//       <td>5.3763341255773</td>
//       <td>54.1132545115121</td>
//       <td>45.35</td>
//       <td>49.2522432701894</td>
//       <td>NA</td>
//       <td>NA</td>
//       <td>12.25</td>
//       <td>48.2178464606181</td>
//       <td>NA</td>
//       <td>NA</td>
//       <td>51.9</td>
//       <td>99.5533901745838</td>
//       <td>96.7</td>
//       <td>100</td>
//       <td>NA</td>
//       <td>NA</td>
//       <td>NA</td>
//       <td>NA</td>
//       <td>NA</td>
//       <td>NA</td>
//       <td>NA</td>
//     </tr>
//     <tr>
//       <th>8035</th>
//       <td>6111980000</td>
//       <td>118</td>
//       <td>Ventura</td>
//       <td>61</td>
//       <td>Unincorporated Ventura County area</td>
//       <td>-119.5035884</td>
//       <td>33.2556547</td>
//       <td>NA</td>
//       <td>NA</td>
//       <td>NA</td>
//       <td>.04259906</td>
//       <td>29.8942128189172</td>
//       <td>5.915569394</td>
//       <td>2.87492221530803</td>
//       <td>.003325882</td>
//       <td>1.4312383322962</td>
//       <td>82.17900035</td>
//       <td>.586986386911452</td>
//       <td>NA</td>
//       <td>NA</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>NA</td>
//       <td>NA</td>
//       <td>4.8</td>
//       <td>41.3960432997387</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>.5</td>
//       <td>22.0847651775487

// %%
*label the unique identifier variable

label var census_tract "Unique identifier"

// %%
*Verifying label
codebook census_tract
// Out:
// -------------------------------------------------------------------------------
// census_tract                                                  Unique identifier
// -------------------------------------------------------------------------------
//
//                   Type: String (str12), but longest is str10
//
//          Unique values: 8,035                     Missing "": 0/8,035
//
//               Examples: "6037191810"
//                         "6037621201"
//                         "6065044804"
//                         "6075032902"

// %%
help encode
// Out:
// [D] encode -- Encode string into numeric and vice versa
//               (View complete PDF manual entry)
//
//
// Syntax
// ------
//
//     String variable to numeric variable
//
//         encode varname [if] [in] , generate(newvar) [label(name) noextend]
//
//
//     Numeric variable to string variable
//
//         decode varname [if] [in] , generate(newvar) [maxlength(#)]
//
//
// Menu
// ----
//
//     encode
//     ------
//
//         Data > Create or change data > Other variable-transformation commands
//             > Encode value labels from string variable
//
//     decode
//     ------
//
//         Data > Create or change data > Other variable-transformation commands
//             > Decode strings from labeled numeric variable
//
//
// Description
// -----------
//
//     encode creates a new variable named newvar based on the string variable
//     varname, creating, adding to, or just using (as necessary) the value
//     label newvar or, if specified, name.  Do not use encode if varname
//     contains numbers that merely happen to be stored as strings; instead, use
//     generate newvar = real(varname) or destring; see real() or [D] destring.
//
//     decode creates a new string variable named newvar based on the "encoded"
//     numeric variable varname and its value label.
//
//
// Links to PDF documentation
// --------------------------
//
//         Quick start
//
//         Remarks and examples
//
//     The above sections are not included in this help file.
//
//
// Options for encode
// ------------------
//
//     generate(newvar) is required and specifies the name of the variable to be
//         created.
//
//     label(name) specifies the name of the value label to be created or used
//         and added to if the named value label already exists.  If label() is
//         not specified, encode uses the same name for the label as it does for
//         the new variable.
//
//     noextend specifies that varname not be encoded if there are values
//         contained in varname that are not present in label(name).  By
//         default, any values not present in label(name) will be added to that
//         label.
//
//
// Options for decode
// ------------------
//
//     generate(newvar) is required and specifies the name of the variable to be
//         created.
//
//     maxlength(#) specifies how many bytes of the value label to retain; #
//         must be between 1 and 32,000.  The default is maxlength(32000).
//
//
// Examples
// --------
//
//     ---------------------------------------------------------------------------
//     Setup
//         . webuse hbp2
//         . describe sex
//
//     Create numeric variable gender based on the string variable sex and
//     create value label gender
//         . encode sex, generate(gender)
//
//     List values of sex and gender
//         . list sex gender in 1/4
//
//     List values of sex and gender, but show numeric values of gender rather
//     than the labels
//         . list sex gender in 1/4, nolabel
//
//     List the names and contents of the gender value label
//         . label list gender
//
//     ---------------------------------------------------------------------------
//     Setup
//         . webuse hbp2, clear
//         . describe sex
//
//     Create numeric variable gender based on the string variable sex and
//     create value label sexlbl
//         . encode sex, generate(gender) label(sexlbl)
//
//     Describe the gender variable
//         . describe gender
//
//     ---------------------------------------------------------------------------
//     Setup
//         . webuse hbp2, clear
//         . describe sex
//
//     Create value label gender
//         . label define gender 1 "female" 2 "male"
//
//     Change the value of sex in the second observation to other
//         . replace sex = "other" in 2
//
//     Create numeric variable gender based on the string variable sex, adding
//     to value label gender as necessary
//         . encode sex, generate(gender)
//
//     List the names and contents of the gender value label
//         . label list gender
//
//     ---------------------------------------------------------------------------
//     Setup
//         . webuse hbp3, clear
//         . describe female
//         . label list sexlbl
//
//     Create string variable sex based on the numeric variable female
//         . decode female, generate(sex)
//
//     Describe variable sex
//         . describe sex
//
//     List values of female and sex
//         . list female sex in 1/4
//
//     List values of female and sex, but show numeric values of female rather
//     than the labels
//         . list female sex in 1/4, nolabel
//     ---------------------------------------------------------------------------
//
//
// Video example
// -------------
//
//         How to convert categorical string variables to labeled numeric
//             variables

// %%
*Like Eaton said, Stata doesn't like string variables. If it doesn't work with vars, may need to use encode to get it to recognize them. 
encode census_tract, gen(census_tract2)

// %%
*Check for missing data overall and within key categories of analysis (time, independent or dependent variable categories, etc)
*codebook gives you the missing values, repeat for the variables that you want to look at

codebook census_tract2
// Out:
// -------------------------------------------------------------------------------
// census_tract2                                                 Unique identifier
// -------------------------------------------------------------------------------
//
//                   Type: Numeric (long)
//                  Label: census_tract2
//
//                  Range: [1,8035]                      Units: 1
//          Unique values: 8,035                     Missing .: 0/8,035
//
//               Examples: 1607  6037191810
//                         3214  6037621201
//                         4821  6065044804
//                         6428  6075032902

// %%
*use summarize to create a table with summary statistics for each variable you plan to analyze
*As noted above, might have to encode all string variables to get stata to do this part next. Then sum all those variables 
*For nominal, have to tab 
sum census_tract2
tab C, missing
// Out:
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
// census_tra~2 |      8,035        4018    2319.649          1       8035
//
//                 C |      Freq.     Percent        Cum.
// ------------------+-----------------------------------
//          Alameda  |        360        4.48        4.48
//           Alpine  |          1        0.01        4.49
//           Amador  |          9        0.11        4.60
//            Butte  |         51        0.63        5.24
//        Calaveras  |         10        0.12        5.36
//           Colusa  |          5        0.06        5.43
//      Contra Costa |        207        2.58        8.00
//         Del Norte |          7        0.09        8.09
//         El Dorado |         42        0.52        8.61
//           Fresno  |        199        2.48       11.09
//            Glenn  |          6        0.07       11.16
//         Humboldt  |         30        0.37       11.54
//         Imperial  |         31        0.39       11.92
//             Inyo  |          6        0.07       12.00
//             Kern  |        151        1.88       13.88
//            Kings  |         27        0.34       14.21
//             Lake  |         15        0.19       14.40
//           Lassen  |          9        0.11       14.51
//       Los Angeles |      2,343       29.16       43.67
//           Madera  |         23        0.29       43.96
//            Marin  |         55        0.68       44.64
//         Mariposa  |          6        0.07       44.72
//        Mendocino  |         20        0.25       44.97
//           Merced  |         49        0.61       45.58
//            Modoc  |          4        0.05       45.63
//             Mono  |          3        0.04       45.66
//         Monterey  |         93        1.16       46.82
//             Napa  |         40        0.50       47.32
//           Nevada  |         20        0.25       47.57
//           Orange  |        582        7.24       54.81
//           Placer  |         84        1.05       55.86
//           Plumas  |          7        0.09       55.94
//        Riverside  |        453        5.64       61.58
//       Sacramento  |        317        3.95       65.53
//        San Benito |         11        0.14       65.66
//    San Bernardino |        369        4.59       70.26
//         San Diego |        627        7.80       78.06
//     San Francisco |        195        2.43       80.49
//       San Joaquin |        139        1.73       82.22
//   San Luis Obispo |         53        0.66       82.87
//         San Mateo |        157        1.95       84.83
//     Santa Barbara |         89        1.11       85.94
//       Santa Clara |        372        4.63       90.57
//        Santa Cruz |         52        0.65       91.21
//           Shasta  |         48        0.60       91.81
//           Sierra  |          1        0.01       91.82
//         Siskiyou  |         14        0.17       92.00
//           Solano  |         96        1.19       93.19
//           Sonoma  |         99        1.23       94.42
//       Stanislaus  |         94        1.17       95.59
//           Sutter  |         21        0.26       95.86
//           Tehama  |         11        0.14       95.99
//          Trinity  |          5        0.06       96.05
//           Tulare  |         78        0.97       97.03
//         Tuolumne  |         11        0.14       97.16
//          Ventura  |        173        2.15       99.32
//             Yolo  |         41        0.51       99.83
//             Yuba  |         14        0.17      100.00
// ------------------+-----------------------------------
//             Total |      8,035      100.00

// %% [markdown]
// ### 3. Write a note summarizing what you learned from browsing the data
//
// [your note here]

// %% [markdown]
// // What should I write for this section? (Some suggestions listed below)
//
// // Is the data cross-sectional or panel data?
// // What years are represented by your data? How many missing data do you have for your key variables?
// // What type of variables (nominal, etc) are the social factors that you are interested in looking at?
// // If your dependent variable is numeric, what is the mean or median?
// // If your dependent variable is categorical, what is the mode?

// %% [markdown]
// ### 4. Create univariate histograms of interval ratio variables you plan to analyze.
//
// Write at least 3 forloops to generate histograms for all the variables you plan to analyze. Create titles for each histogram that notes whether it is a dependent, independent, or control variable (you can also note in titles whether control vars control for spurious, intervening, or interactive relationships). Begin with your dependent variables. Then make a note below to describe the shapes of the distributions and their implications for your study.
//
// [your note here]

// %%
// Summary of question 4: Charlie is basically asking you to create histograms with titles for all your numeric variables


*Self note: would need to change the var and title depending on the variable. As Anh says, this is only for numeric variables that we choose 
*census looks weird because it's bundling obs together most likely. like 600*-600*
histogram census_tract2, frequency title("Census Tract")
// Out:
// (bin=39, start=1, width=206)

// %% [markdown]
// ### 5. Create univariate count and % frequency tables for all categorical (nominal) variables you plan to analyze
//
// Again, use forloops. Then write a note below with a narrative summary of the distributions and their implications for your study.
//
// [your note here]

// %%
encode C, gen(C2)

// %%
*Add all of the variables you want after census_tract2. I tried it with nominal variable below and it worked pretty well. Then the loop should just run (Stata might freak out about any string vars.
// Encode them and then it will cooperate)
foreach x of varlist C2 {
    replace `x'=. if `x'==.i | `x'==.n | `x'==.d
    tab `x' in 1/40, missing
}
// Out:
// (0 real changes made)
//
//              C2 |      Freq.     Percent        Cum.
// ----------------+-----------------------------------
//         Fresno  |          8       20.00       20.00
//           Kern  |          1        2.50       22.50
//     Los Angeles |         26       65.00       87.50
//  San Bernardino |          1        2.50       90.00
//     San Joaquin |          3        7.50       97.50
//     Stanislaus  |          1        2.50      100.00
// ----------------+-----------------------------------
//           Total |         40      100.00

// %% [markdown]
// ### 6. Make a relevant bivariate table and graph for your study
//
// Make the appropriate a) bivariate table and b) graph dependening on whether your dependent variable is nominal/categorical or interval ratio. If your dependent variable is nominal, make sure it is the row variable in the table. If your independent variable is interval ratio, convert it into an ordinal variable by creating a new variable with 3 to 5 categories each with an equal range of the interval ratio variable. Then use the new ordinal variable as your independent variable in the bivariate table and graph.

// %%
%help tab
// Out:
// This front-end cannot display HTML help.

// %%
*This gives you the bivariate table part. Doing 'in #/#' gives you only a set number of obs so it doesn't get crazy long. //
// Need a dependent variable and independent, then look at the directions 
tab C2 census_tract2 in 1/40
// Out:
//                 |              Unique identifier
//              C2 | 601900020  601900030  601900040  601900070 |     Total
// ----------------+--------------------------------------------+----------
//         Fresno  |         1          1          1          1 |         8
//           Kern  |         0          0          0          0 |         1
//     Los Angeles |         0          0          0          0 |        26
//  San Bernardino |         0          0          0          0 |         1
//     San Joaquin |         0          0          0          0 |         3
//     Stanislaus  |         0          0          0          0 |         1
// ----------------+--------------------------------------------+----------
//           Total |         1          1          1          1 |        40
//
//
//                 |              Unique identifier
//              C2 | 601900090  601900100  601900110  601900120 |     Total
// ----------------+--------------------------------------------+----------
//         Fresno  |         1          1          1          1 |         8
//           Kern  |         0          0          0          0 |         1
//     Los Angeles |         0          0          0          0 |        26
//  San Bernardino |         0          0          0          0 |         1
//     San Joaquin |         0          0          0          0 |         3
//     Stanislaus  |         0          0          0          0 |         1
// ----------------+--------------------------------------------+----------
//           Total |         1          1          1          1 |        40
//
//
//                 |              Unique identifier
//              C2 | 602900250  603710470  603720330  603720492 |     Total
// ----------------+--------------------------------------------+----------
//         Fresno  |         0          0          0          0 |         8
//           Kern  |         1          0          0          0 |         1
//     Los Angeles |         0          1          1          1 |        26
//  San Bernardino |         0          0          0          0 |         1
//     San Joaquin |         0          0          0          0 |         3
//     Stanislaus  |         0          0          0          0 |         1
// ----------------+--------------------------------------------+----------
//           Total |         1          1          1          1 |        40
//
//
//                 |              Unique identifier
//              C2 | 603720512  603720605  603722600  603722600 |     Total
// ----------------+--------------------------------------------+----------
//         Fresno  |         0          0          0          0 |         8
//           Kern  |         0          0          0          0 |         1
//     Los Angeles |         1          1          1          1 |        26
//  San Bernardino |         0          0          0          0 |         1
//     San Joaquin |         0          0          0          0 |         3
//     Stanislaus  |         0          0          0          0 |         1
// ----------------+--------------------------------------------+----------
//           Total |         1          1          1          1 |        40
//
//
//                 |              Unique identifier
//              C2 | 603722701  603723920  603724050  603724260 |     Total
// ----------------+--------------------------------------------+----------
//         Fresno  |         0          0          0          0 |         8
//           Kern  |         0          0          0          0 |         1
//     Los Angeles |         1          1          1          1 |        26
//  San Bernardino |         0          0          0          0 |         1
//     San Joaquin |         0          0          0          0 |         3
//     Stanislaus  |         0          0          0          0 |         1
// ----------------+--------------------------------------------+----------
//           Total |         1          1          1          1 |        40
//
//
//                 |              Unique identifier
//              C2 | 603724270  603724310  603729121  603729122 |     Total
// ----------------+--------------------------------------------+----------
//         Fresno  |         0          0          0          0 |         8
//           Kern  |         0          0          0          0 |         1
//     Los Angeles |         1          1          1          1 |        26
//  San Bernardino |         0          0          0          0 |         1
//     San Joaquin |         0          0          0          0 |         3
//     Stanislaus  |         0          0          0          0 |         1
// ----------------+--------------------------------------------+----------
//           Total |         1          1          1          1 |        40
//
//
//                 |              Unique identifier
//              C2 | 603743310  603743350  603753130  603753230 |     Total
// ----------------+--------------------------------------------+----------
//         Fresno  |         0          0          0          0 |         8
//           Kern  |         0          0          0          0 |         1
//     Los Angeles |         1          1          1          1 |        26
//  San Bernardino |         0          0          0          0 |         1
//     San Joaquin |         0          0          0          0 |         3
//     Stanislaus  |         0          0          0          0 |         1
// ----------------+--------------------------------------------+----------
//           Total |         1          1          1          1 |        40
//
//
//                 |              Unique identifier
//              C2 | 603753420  603753540  603753610  603754220 |     Total
// ----------------+--------------------------------------------+----------
//         Fresno  |         0          0          0          0 |         8
//           Kern  |         0          0          0          0 |         1
//     Los Angeles |         1          1          1          1 |        26
//  San Bernardino |         0          0          0          0 |         1
//     San Joaquin |         0          0          0          0 |         3
//     Stanislaus  |         0          0          0          0 |         1
// ----------------+--------------------------------------------+----------
//           Total |         1          1          1          1 |        40
//
//
//                 |              Unique identifier
//              C2 | 603754240  603754320  603757040  607100160 |     Total
// ----------------+--------------------------------------------+----------
//         Fresno  |         0          0          0          0 |         8
//           Kern  |         0          0          0          0 |         1
//     Los Angeles |         1          1          1          0 |        26
//  San Bernardino |         0          0          0          1 |         1
//     San Joaquin |         0          0          0          0 |         3
//     Stanislaus  |         0          0          0          0 |         1
// ----------------+--------------------------------------------+----------
//           Total |         1          1          1          1 |        40
//
//
//                 |              Unique identifier
//              C2 | 607700010  607700030  607700070  609900370 |     Total
// ----------------+--------------------------------------------+----------
//         Fresno  |         0          0          0          0 |         8
//           Kern  |         0          0          0          0 |         1
//     Los Angeles |         0          0          0          0 |        26
//  San Bernardino |         0          0          0          0 |         1
//     San Joaquin |         1          1          1          0 |         3
//     Stanislaus  |         0          0          0          1 |         1
// ----------------+--------------------------------------------+----------
//           Total |         1          1          1          1 |        40

// %% [markdown]
// ### 7. Create partial bivariate tables and graphs
//
// For the bivariate table and graph you made for problem 6, split both into partial tables and graphs using one of your nominal/categorical control variables. If your control variable is interval ratio, convert it into an ordinal variable by creating a variable with 3 to 5 categories each with an equal range of the interval ratio variable.  Then use the new ordinal variable as your control variable to create the partial tables and graphs.

// %% [markdown]
// ### Interpret of your bivariate and partial tables and graphs
//
// Is there a relationship between your dependent and independent variables? Is it weak, strong, or non-existent? Do adding controls reveal any spurious, intervening, or interactive relationships? Do they conform with your hypotheses? If not, do you have any ideas for why and how you might test the reason why?
